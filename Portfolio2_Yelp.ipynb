# %% [markdown]
# ## Analysis of Yelp Dataset Portfolio2

# %% [markdown]
# The portfolio aims to use various data processing techniques to clean and preprocess the data, filter out irrelevant data, and remove any outliers that could impact the accuracy of the model. Finally, the portfolio aims to use linear regression models to train and validate the model's accuracy in predicting user ratings towards business. Ultimately, the objective is to build a reliable model that can be used to provide insights into user preferences and help businesses make data-driven decisions to improve their services and offerings. In this task, we will explore the impacts of feature selections and different sizes of training/testing data on the model performance. We will use Yelp sub-dataset.

# %% [markdown]
# ### Import the output sample data from Portfolio1
# The csv file named `Yelp_Portfolio2_Input.csv` is provided. You may need to use the Pandas method, i.e., `read_csv`, for doing this. After that, please import the csv file and print out its total length.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import r2_score

import seaborn as sns
import matplotlib.pylab as plt
# %matplotlib inline

# %%
sample_data = pd.read_csv('files/Yelp_Portfolio2_Input.csv')
print(len(sample_data))
# Out:
# 38654

# %%
sample_data.head()
# Out:
#             business_categories business_city             business_id  \
# 0   Middle Eastern; Restaurants         Tempe  6oRAC4uyJCsJl1X0WZpVSA
# 1         Tattoo; Beauty & Spas         Tempe  WGNIYMeXPyoWav1APUq7jA
# 2             Tires; Automotive      Glendale  rxQ2PIjhAx6dgAqUalf99Q
# 3       Sushi Bars; Restaurants         Tempe  EC9WB-iVjd28B6R6KIZ8TA
# 4  Arts & Entertainment; Cinema         Tempe  LDJhwZN14AZOJyHjg2lkRw
#
#          date  stars                                               text  \
# 0   14/6/2012      4  love the gyro plate. Rice is so good and I als...
# 1  23/12/2011      4  Good tattoo shop. Clean space, multiple artist...
# 2    9/9/2012      5  Never having dealt with a Discount Tire in Pho...
# 3    4/8/2010      4  Cliff notes\n- Cheap: $1-2/plate\n- Fast: It's...
# 4  13/12/2011      4  We got passes for the preview of Mission Impos...
#
#    useful                 user_id
# 0       1  0hT2KtfLiobPvh6cDC8JQg
# 1       2  Xm8HXE1JHqscXe5BKf0GFQ
# 2       0  HLbhD2OyiMCUDRR4c1iXaw
# 3       0  jdoGEEy5s-5L1O_lNzEi2g
# 4       0  Mb0psF4WQF7gZSuZafVr-g

# %% [markdown]
# # Q1. `business_categories` processing

# %% [markdown]
# You may notice that there are a total of 693 unique business categories present in the sample data. Please write a code snippet to confirm this number. Then, generate a boxplot of `stars` for `business_categories`.

# %%
# your code and solutions

# %%
len(sample_data['business_categories'].value_counts())
# Out:
# 693

# %% [markdown]
# Sometimes we need to extract some major categories, such as `Middle Eastern; Restaurants` and `Sushi Bars; Restaurants`, both of which should belong to the `Restaurants` category.

# %%
bc_list = list(sample_data['business_categories'])
type(bc_list)
# Out:
# list

# %%
catdict = {}
for bc in bc_list:
    bstr = str(bc)
    ch = ';'
    if ch in bstr:
        temp = bstr.split(';')
        x = (len(temp)) - 1
        if temp[x] not in catdict.keys():
            catdict[temp[x]] = 1
        elif temp[x] in catdict.keys():
            catdict[temp[x]] += 1

# %%
catdict
# Out:
# {' Restaurants': 25023,
#  ' Beauty & Spas': 475,
#  ' Automotive': 324,
#  ' Cinema': 218,
#  ' Coffee & Tea': 1116,
#  ' Furniture Stores': 218,
#  " Men's Clothing": 69,
#  ' Fitness & Instruction': 336,
#  ' Gas & Service Stations': 62,
#  ' Hotels': 528,
#  ' Shopping': 1054,
#  ' Grocery': 390,
#  ' Food': 95,
#  ' Music Venues': 348,
#  ' Venues & Event Spaces': 69,
#  ' Nightlife': 372,
#  ' Beer, Wine & Spirits': 242,
#  ' Fashion': 6,
#  ' Italian': 960,
#  ' Arts & Entertainment': 59,
#  ' Education': 71,
#  ' Convenience Stores': 37,
#  ' Ice Cream & Frozen Yogurt': 728,
#  ' Event Planning & Services': 117,
#  ' Rafting/Kayaking': 9,
#  ' Accessories': 66,
#  ' Bakeries': 64,
#  ' Lounges': 109,
#  ' Performing Arts': 112,
#  ' Desserts': 183,
#  ' Chocolatiers & Shops': 45,
#  ' Apartments': 52,
#  ' Juice Bars & Smoothies': 39,
#  ' Pets': 166,
#  ' Public Services & Government': 85,
#  ' Nail Salons': 219,
#  ' Specialty Food': 230,
#  ' Arts & Crafts': 40,
#  ' Bowling': 37,
#  ' Department Stores': 24,
#  ' Caterers': 78,
#  ' Donuts': 116,
#  ' Drugstores': 93,
#  ' Sports Wear': 90,
#  ' Stadiums & Arenas': 275,
#  ' Street Vendors': 6,
#  ' General Dentistry': 37,
#  ' Real Estate': 15,
#  ' Shoe Stores': 44,
#  ' Urgent Care': 56,
#  ' Horseback Riding': 15,
#  ' Bookstores': 208,
#  ' Auto Glass Services': 42,
#  ' Home Theatre Installation': 28,
#  ' Auto Parts & Supplies': 50,
#  ' Outlet Stores': 6,
#  ' Lakes': 31,
#  ' Financial Services': 37,
#  ' Sewing & Alterations': 40,
#  ' Adult': 11,
#  ' Mobile Phones': 52,
#  ' Body Shops': 40,
#  ' Sports Bars': 50,
#  ' Home Services': 110,
#  ' Home & Garden': 68,
#  ' Appliances': 48,
#  ' Preschools': 3,
#  ' Shoe Repair': 18,
#  ' Golf': 49,
#  ' Amusement Parks': 72,
#  ' Contractors': 45,
#  ' Car Dealers': 71,
#  ' Farmers Market': 47,
#  ' Breweries': 79,
#  ' Flowers & Gifts': 31,
#  ' Parks': 163,
#  ' Festivals': 12,
#  ' Turkish': 85,
#  ' Kids Activities': 10,
#  ' Hospitals': 38,
#  ' Professional Services': 9,
#  ' Amateur Sports Teams': 6,
#  ' Religious Organizations': 8,
#  ' Pet Stores': 59,
#  ' Baby Gear & Furniture': 31,
#  ' Fast Food': 11,
#  ' Health & Medical': 48,
#  ' Comedy Clubs': 67,
#  ' Travel Services': 5,
#  ' Professional Sports Teams': 18,
#  ' Transportation': 51,
#  ' Fabric Stores': 8,
#  ' Dry Cleaning & Laundry': 87,
#  ' Dance Clubs': 37,
#  ' Antiques': 44,
#  ' Community Service/Non-Profit': 15,
#  ' Photography Stores & Services': 34,
#  ' Formal Wear': 5,
#  ' Swimming Pools': 5,
#  ' Mass Media': 10,
#  ' Medical Spas': 23,
#  ' Karaoke': 48,
#  ' Web Design': 4,
#  ' Printing Services': 16,
#  ' Party & Event Planning': 11,
#  ' Naturopathic/Holistic': 16,
#  ' Psychics & Astrologers': 3,
#  ' Electronics': 20,
#  ' Cosmetics & Beauty Supply': 12,
#  ' Wholesale Stores': 14,
#  ' Dentists': 8,
#  ' Active Life': 7,
#  ' Food Delivery Services': 9,
#  ' Car Rental': 18,
#  " Children's Clothing": 26,
#  ' Shipping Centers': 18,
#  ' Motorcycle Dealers': 9,
#  ' Chiropractors': 10,
#  ' Toy Stores': 24,
#  ' Pizza': 23,
#  ' Orthodontists': 3,
#  ' IT Services & Computer Repair': 14,
#  ' Leisure Centers': 5,
#  ' Pawn Shops': 14,
#  ' Graphic Design': 4,
#  ' Hiking': 12,
#  ' Internet Cafes': 6,
#  ' Sandwiches': 31,
#  ' Cosmetic Dentists': 16,
#  ' Bike Rentals': 44,
#  ' Books, Mags, Music & Video': 11,
#  ' Internal Medicine': 15,
#  ' Brazilian': 4,
#  ' Bagels': 29,
#  ' Pediatricians': 9,
#  ' Eyewear & Opticians': 11,
#  ' Tires': 16,
#  ' Physical Therapy': 3,
#  ' Office Equipment': 18,
#  ' Hobby Shops': 3,
#  ' Home Decor': 16,
#  ' Appliances & Repair': 15,
#  ' Heating & Air Conditioning/HVAC': 12,
#  ' Oil Change Stations': 23,
#  ' Jewelry': 24,
#  ' Outdoor Gear': 8,
#  ' Archery': 4,
#  ' Pest Control': 17,
#  ' Wineries': 13,
#  ' Meat Shops': 3,
#  ' Radio Stations': 16,
#  ' Obstetricians & Gynecologists': 6,
#  ' Insurance': 11,
#  ' Arcades': 17,
#  ' Florists': 17,
#  ' Internet Service Providers': 3,
#  ' Towing': 4,
#  ' Tours': 3,
#  ' Furniture Reupholstery': 6,
#  ' Flooring': 3,
#  ' Guns & Ammo': 4,
#  ' Shopping Centers': 3,
#  ' Real Estate Agents': 7,
#  ' Tennis': 10,
#  ' Candy Stores': 17,
#  ' Bed & Breakfast': 3,
#  ' Notaries': 3,
#  ' Music & DVDs': 7,
#  ' Social Clubs': 11,
#  ' Self Storage': 7,
#  ' General Litigation': 8,
#  ' Photographers': 4,
#  ' Costumes': 4,
#  ' Auto Repair': 3,
#  ' Junk Removal & Hauling': 3,
#  ' Session Photography': 3,
#  ' Laser Hair Removal': 6,
#  ' Public Transportation': 3,
#  ' RV Dealers': 3,
#  ' Doctors': 3}

# %% [markdown]
# ### Q1.1 How to efficiently and accurately extract the last category value (i.e., categorieN) from the `business_categories` column in a dataset, where the format of each row is a semicolon-separated list of categories (i.e., 'categorie1; categorie2;...;categorieN')? and replace the original string with this last category value. At last, print the first five rows.

# %%
for bc in bc_list:
    temp = (str(bc)).split(';')
    l = (len(temp)) - 1
    ind = bc_list.index(bc)
    bc_list[ind] = temp[l]

# %%
dict_d = {'bc':bc_list}
df = pd.DataFrame(dict_d)

# %%
sample_data.business_categories = df.bc

# %%
df_c = sample_data['business_categories']

# %%
df_c.head()
# Out:
# 0       Restaurants
# 1     Beauty & Spas
# 2        Automotive
# 3       Restaurants
# 4            Cinema
# Name: business_categories, dtype: object

# %%
len(sample_data['business_categories'].value_counts())
# Out:
# 195

# %% [markdown]
# ### Q1.2 Let's first check how many unique business categories are present in the dataset (output from Q1.1). Maybe it's still not an appropriate number to make a clear Boxplot. Now, we want to display `ALL Rows` of the business category count data. That is to count and print the number of occurrences for each business category.

# %%
# your code and solutions

# %%
len(sample_data['business_categories'].value_counts())
# Out:
# 195

# %%
dict_occur = {}
for b in bc_list:
    if b not in dict_occur.keys():
        dict_occur[b] = 1
    else:
        dict_occur[b] += 1

# %%
dict_occur
# Out:
# {' Restaurants': 25023,
#  ' Beauty & Spas': 475,
#  ' Automotive': 324,
#  ' Cinema': 218,
#  ' Coffee & Tea': 1116,
#  ' Furniture Stores': 218,
#  'Religious Organizations': 7,
#  " Men's Clothing": 69,
#  ' Fitness & Instruction': 336,
#  ' Gas & Service Stations': 62,
#  ' Hotels': 528,
#  ' Shopping': 1054,
#  ' Grocery': 390,
#  ' Food': 95,
#  ' Music Venues': 348,
#  ' Venues & Event Spaces': 69,
#  ' Nightlife': 372,
#  ' Beer, Wine & Spirits': 242,
#  ' Fashion': 6,
#  ' Italian': 960,
#  ' Arts & Entertainment': 59,
#  ' Education': 71,
#  ' Convenience Stores': 37,
#  ' Ice Cream & Frozen Yogurt': 728,
#  ' Event Planning & Services': 117,
#  ' Rafting/Kayaking': 9,
#  ' Accessories': 66,
#  ' Bakeries': 64,
#  'Restaurants': 189,
#  ' Lounges': 109,
#  ' Performing Arts': 112,
#  ' Desserts': 183,
#  ' Chocolatiers & Shops': 45,
#  ' Apartments': 52,
#  ' Juice Bars & Smoothies': 39,
#  ' Pets': 166,
#  ' Public Services & Government': 85,
#  ' Nail Salons': 219,
#  ' Specialty Food': 230,
#  ' Arts & Crafts': 40,
#  ' Bowling': 37,
#  ' Department Stores': 24,
#  ' Caterers': 78,
#  ' Donuts': 116,
#  ' Drugstores': 93,
#  'Arts & Entertainment': 15,
#  ' Sports Wear': 90,
#  ' Stadiums & Arenas': 275,
#  ' Street Vendors': 6,
#  ' General Dentistry': 37,
#  ' Real Estate': 15,
#  ' Shoe Stores': 44,
#  ' Urgent Care': 56,
#  ' Horseback Riding': 15,
#  ' Bookstores': 208,
#  ' Auto Glass Services': 42,
#  ' Home Theatre Installation': 28,
#  ' Auto Parts & Supplies': 50,
#  ' Outlet Stores': 6,
#  ' Lakes': 31,
#  ' Financial Services': 37,
#  ' Sewing & Alterations': 40,
#  ' Adult': 11,
#  ' Mobile Phones': 52,
#  ' Body Shops': 40,
#  ' Sports Bars': 50,
#  ' Home Services': 110,
#  ' Home & Garden': 68,
#  ' Appliances': 48,
#  ' Preschools': 3,
#  ' Shoe Repair': 18,
#  ' Golf': 49,
#  ' Amusement Parks': 72,
#  ' Contractors': 45,
#  ' Car Dealers': 71,
#  ' Farmers Market': 47,
#  ' Breweries': 79,
#  ' Flowers & Gifts': 31,
#  ' Parks': 163,
#  ' Festivals': 12,
#  ' Turkish': 85,
#  'Food': 15,
#  ' Kids Activities': 10,
#  ' Hospitals': 38,
#  ' Professional Services': 9,
#  ' Amateur Sports Teams': 6,
#  ' Religious Organizations': 8,
#  ' Pet Stores': 59,
#  ' Baby Gear & Furniture': 31,
#  ' Fast Food': 11,
#  ' Health & Medical': 48,
#  ' Comedy Clubs': 67,
#  ' Travel Services': 5,
#  ' Professional Sports Teams': 18,
#  ' Transportation': 51,
#  ' Fabric Stores': 8,
#  ' Dry Cleaning & Laundry': 87,
#  ' Dance Clubs': 37,
#  ' Antiques': 44,
#  ' Community Service/Non-Profit': 15,
#  ' Photography Stores & Services': 34,
#  'Shopping': 45,
#  ' Formal Wear': 5,
#  'Home Services': 3,
#  ' Swimming Pools': 5,
#  ' Mass Media': 10,
#  ' Medical Spas': 23,
#  ' Karaoke': 48,
#  ' Web Design': 4,
#  ' Printing Services': 16,
#  ' Party & Event Planning': 11,
#  ' Naturopathic/Holistic': 16,
#  'Local Flavor': 36,
#  ' Psychics & Astrologers': 3,
#  ' Electronics': 20,
#  ' Cosmetics & Beauty Supply': 12,
#  ' Wholesale Stores': 14,
#  ' Dentists': 8,
#  ' Active Life': 7,
#  ' Food Delivery Services': 9,
#  ' Car Rental': 18,
#  " Children's Clothing": 26,
#  ' Shipping Centers': 18,
#  ' Motorcycle Dealers': 9,
#  ' Chiropractors': 10,
#  ' Toy Stores': 24,
#  ' Pizza': 23,
#  ' Orthodontists': 3,
#  ' IT Services & Computer Repair': 14,
#  ' Leisure Centers': 5,
#  ' Pawn Shops': 14,
#  ' Graphic Design': 4,
#  ' Hiking': 12,
#  ' Internet Cafes': 6,
#  ' Sandwiches': 31,
#  ' Cosmetic Dentists': 16,
#  ' Bike Rentals': 44,
#  'Nightlife': 27,
#  ' Books, Mags, Music & Video': 11,
#  ' Internal Medicine': 15,
#  ' Brazilian': 4,
#  ' Bagels': 29,
#  ' Pediatricians': 9,
#  'Local Services': 11,
#  ' Eyewear & Opticians': 11,
#  'Public Services & Government': 7,
#  ' Tires': 16,
#  ' Physical Therapy': 3,
#  ' Office Equipment': 18,
#  ' Hobby Shops': 3,
#  ' Home Decor': 16,
#  ' Appliances & Repair': 15,
#  ' Heating & Air Conditioning/HVAC': 12,
#  ' Oil Change Stations': 23,
#  ' Jewelry': 24,
#  ' Outdoor Gear': 8,
#  ' Archery': 4,
#  ' Pest Control': 17,
#  ' Wineries': 13,
#  'Health & Medical': 4,
#  'Active Life': 36,
#  ' Meat Shops': 3,
#  ' Radio Stations': 16,
#  ' Obstetricians & Gynecologists': 6,
#  ' Insurance': 11,
#  ' Arcades': 17,
#  ' Florists': 17,
#  ' Internet Service Providers': 3,
#  ' Towing': 4,
#  ' Tours': 3,
#  ' Furniture Reupholstery': 6,
#  ' Flooring': 3,
#  ' Guns & Ammo': 4,
#  ' Shopping Centers': 3,
#  ' Real Estate Agents': 7,
#  ' Tennis': 10,
#  ' Candy Stores': 17,
#  ' Bed & Breakfast': 3,
#  ' Notaries': 3,
#  'Professional Services': 3,
#  ' Music & DVDs': 7,
#  ' Social Clubs': 11,
#  ' Self Storage': 7,
#  ' General Litigation': 8,
#  ' Photographers': 4,
#  ' Costumes': 4,
#  ' Auto Repair': 3,
#  'Automotive': 10,
#  ' Junk Removal & Hauling': 3,
#  ' Session Photography': 3,
#  ' Laser Hair Removal': 6,
#  ' Public Transportation': 3,
#  'Education': 2,
#  ' RV Dealers': 3,
#  ' Doctors': 3}

# %% [markdown]
# ### Q1.3 We want to remove categories that appear fewer than 200 times. Write a Python code snippet to perform this operation. At last, print the number of resulting unique business_categories.

# %%
# your code and solutions

# %%
bdict = {}
for occ in dict_occur.keys():
    if (dict_occur[occ] >= 200):
        bdict[occ] = dict_occur[occ]

# %%
bdict
# Out:
# {' Restaurants': 25023,
#  ' Beauty & Spas': 475,
#  ' Automotive': 324,
#  ' Cinema': 218,
#  ' Coffee & Tea': 1116,
#  ' Furniture Stores': 218,
#  ' Fitness & Instruction': 336,
#  ' Hotels': 528,
#  ' Shopping': 1054,
#  ' Grocery': 390,
#  ' Music Venues': 348,
#  ' Nightlife': 372,
#  ' Beer, Wine & Spirits': 242,
#  ' Italian': 960,
#  ' Ice Cream & Frozen Yogurt': 728,
#  ' Nail Salons': 219,
#  ' Specialty Food': 230,
#  ' Stadiums & Arenas': 275,
#  ' Bookstores': 208}

# %%
unique_b = list(bdict.keys())

# %%
len(unique_b)
# Out:
# 19

# %%
for bs in sample_data['business_categories']:
    if bs not in unique_b:
        sample_data = sample_data.drop(sample_data[sample_data.business_categories == bs].index)

# %%
sample_data.head()
# Out:
#   business_categories business_city             business_id        date  \
# 0         Restaurants         Tempe  6oRAC4uyJCsJl1X0WZpVSA   14/6/2012
# 1       Beauty & Spas         Tempe  WGNIYMeXPyoWav1APUq7jA  23/12/2011
# 2          Automotive      Glendale  rxQ2PIjhAx6dgAqUalf99Q    9/9/2012
# 3         Restaurants         Tempe  EC9WB-iVjd28B6R6KIZ8TA    4/8/2010
# 4              Cinema         Tempe  LDJhwZN14AZOJyHjg2lkRw  13/12/2011
#
#    stars                                               text  useful  \
# 0      4  love the gyro plate. Rice is so good and I als...       1
# 1      4  Good tattoo shop. Clean space, multiple artist...       2
# 2      5  Never having dealt with a Discount Tire in Pho...       0
# 3      4  Cliff notes\n- Cheap: $1-2/plate\n- Fast: It's...       0
# 4      4  We got passes for the preview of Mission Impos...       0
#
#                   user_id
# 0  0hT2KtfLiobPvh6cDC8JQg
# 1  Xm8HXE1JHqscXe5BKf0GFQ
# 2  HLbhD2OyiMCUDRR4c1iXaw
# 3  jdoGEEy5s-5L1O_lNzEi2g
# 4  Mb0psF4WQF7gZSuZafVr-g

# %%
len(sample_data['business_categories'].value_counts())
# Out:
# 19

# %%
(sample_data['business_categories'].count())
# Out:
# 33264

# %%
len(sample_data.index)
# Out:
# 33264

# %% [markdown]
# # Q2. Outliers

# %% [markdown]
# ### Q2.1 Remove any rows from the sample_data DataFrame (output from Q1.3) where the `useful` column has a value of 6 or more; Then, create a single figure with two subplots, one showing the boxplot of `useful` column of the original data and the other showing the boxplot of the data with outliers removed.
#
# At last, __print the length of the data__.

# %%
# your code and solutions

# %%
df1 =pd.DataFrame({'useful': list(sample_data['useful']), 'ur': np.repeat(0,33264)})

# %%
sample_data[sample_data.useful >= 6] = np.nan
df2 = pd.DataFrame({'useful': list(sample_data['useful']),'ur': np.repeat(1,33264)})

# %%
df3 = sample_data[sample_data.useful < 6]

# %%
pd.concat([df1,df2]).boxplot(column='useful',by='ur')
# Out:
# <AxesSubplot:title={'center':'useful'}, xlabel='ur'>

# %%
len(list(df3['useful']))
# Out:
# 32330

# %% [markdown]
# ### Q2.2 In general, we might remove some inactive users from a dataset (output from Q2.1), for example, users who rate businesses less than 3 times. However, in this case, we are doing the opposite and removing extremely active users who rate businesses more than 30 times (>30). Again, create a single figure with two subplots, one showing the boxplot of the count of business rating given by each user and the other showing the boxplot of the data with outliers removed.
#
# At last, __print the length of the data__.

# %%
df3.head()
# Out:
#   business_categories business_city             business_id        date  \
# 0         Restaurants         Tempe  6oRAC4uyJCsJl1X0WZpVSA   14/6/2012
# 1       Beauty & Spas         Tempe  WGNIYMeXPyoWav1APUq7jA  23/12/2011
# 2          Automotive      Glendale  rxQ2PIjhAx6dgAqUalf99Q    9/9/2012
# 3         Restaurants         Tempe  EC9WB-iVjd28B6R6KIZ8TA    4/8/2010
# 4              Cinema         Tempe  LDJhwZN14AZOJyHjg2lkRw  13/12/2011
#
#    stars                                               text  useful  \
# 0    4.0  love the gyro plate. Rice is so good and I als...     1.0
# 1    4.0  Good tattoo shop. Clean space, multiple artist...     2.0
# 2    5.0  Never having dealt with a Discount Tire in Pho...     0.0
# 3    4.0  Cliff notes\n- Cheap: $1-2/plate\n- Fast: It's...     0.0
# 4    4.0  We got passes for the preview of Mission Impos...     0.0
#
#                   user_id
# 0  0hT2KtfLiobPvh6cDC8JQg
# 1  Xm8HXE1JHqscXe5BKf0GFQ
# 2  HLbhD2OyiMCUDRR4c1iXaw
# 3  jdoGEEy5s-5L1O_lNzEi2g
# 4  Mb0psF4WQF7gZSuZafVr-g

# %%
exactive = {}
for uid in df3.user_id:
    if uid not in exactive.keys():
        exactive[uid] = 1
    else:
        exactive[uid] += 1

# %%
exactive
# Out:
# {'0hT2KtfLiobPvh6cDC8JQg': 2,
#  'Xm8HXE1JHqscXe5BKf0GFQ': 42,
#  'HLbhD2OyiMCUDRR4c1iXaw': 2,
#  'jdoGEEy5s-5L1O_lNzEi2g': 5,
#  'Mb0psF4WQF7gZSuZafVr-g': 10,
#  'xw77viWz_BbmyntxoBVH4A': 2,
#  'EPROVap0M19Y6_4uf3eCmQ': 4,
#  'gTCM7qlVrwdml-hFB6aJqQ': 14,
#  'aLTl_OkLo0BFRxdz1n6sYA': 11,
#  'O3huqF3nBeWP9Zd6NmCAaQ': 7,
#  'YBVdmm5zlpLpi2_DiKsd2A': 2,
#  'Gi_ZP3Pjdvc9-a8aS3SH0A': 3,
#  'thlVIc8s6ZCP37UGMf3yDA': 17,
#  '8-2W5CmkDl9vrkxRpkiPRg': 26,
#  'jKeaOrPyJ-dI9SNeVqrbww': 23,
#  '4B6aJJTELjivUXrL_LTlqQ': 1,
#  'rVlgz-MGYRPa8UzTYO0RGQ': 6,
#  '1wMGLaMIH7CcmJ2htS1rmw': 16,
#  '_PzSNcfrCjeBxSLXRoMmgQ': 77,
#  'b60JsTGYbVqUGYbI81aOsw': 24,
#  'YPk47NcyWSkk-541OxyzMQ': 25,
#  'nH0YyEYTE7RMeAbeERrSQA': 3,
#  'pRw80rCPUTcBo2Zv5De1yQ': 1,
#  '6OWHDbEq23f24Vki_veHBA': 50,
#  'ETIAM78kYT_xPM8b2iqi7g': 8,
#  'px6RIT_CcE2Z1Jd52C8TQQ': 8,
#  'X5GbNXY_nNoa_vTZDD0aCA': 58,
#  'lAngRi4lwBIHmjCBVLd-8Q': 6,
#  'Pk5T0OFCbl8mIKkKYyglWQ': 9,
#  'KucBnMrhalzxnD9AWrxwYQ': 13,
#  'vOw4NYgKe57qcJ5fOjk6PQ': 4,
#  '7kRN8IkOWlLblEltNlnfRQ': 10,
#  'VyzwBKnq-LJ8OjvG0ZTwrg': 4,
#  'EO5Q9yRT7LP00iQYpSNuhw': 1,
#  'K0euQLFAcKhQPZ6JxGAryg': 38,
#  'qQb4pg5uqvjMOfGPWbIkeQ': 44,
#  'PzeWNJ_hrhDzs8NdcBA06A': 1,
#  '23iaSkV0K36OetsHnXLoYQ': 1,
#  'EIQ8gPTx5L-zXPlYDwWGeg': 1,
#  'LKJswnMTubEGjJXFDseHKA': 2,
#  'DA_SU_MbfgfalzbktcsBzw': 1,
#  '8qe2c5uRlAkvNFvDriBm1Q': 20,
#  '_OLBq0aZR7K-UdPCrByatg': 2,
#  'Zgp9T6IOVFOozrWDw_mUGQ': 5,
#  'nbofxFWHORebBHh10OgYLA': 18,
#  'vKs0r5yZhfJYdBSd0J1a3Q': 1,
#  '80PHOfM8KOBb7xEQN4C0lg': 3,
#  '44FZYP4fQbeAimA818oHtw': 1,
#  'qABKRj1ggJmtvrL9FMFtuA': 23,
#  'Ps1Db9zOatoF_76FZNO5CQ': 50,
#  'yov4PgFnEIOimzKdU2wV0g': 1,
#  'ZdDmxmGVhHHI4PzmVdTzxQ': 6,
#  '_jjIaczpcVDpHlH6l334rQ': 7,
#  'oMDSmhe72hjxoR3EAj6sXQ': 5,
#  'El1Q48x6ZfofQmaBZTrduQ': 1,
#  'chI2p-ROg2tXI2-tT2_G2A': 28,
#  'Xffah_1oR1AYdi3TiW9Ckw': 1,
#  'gh2OwESXrgVyufGz_NPHxw': 2,
#  'Jrx1fLr5JdqgHdIfMT7wag': 6,
#  'yneTxW_9TTRXTOgJDH9fnQ': 2,
#  'UCQNrwN4_hHHTWYa8cqe_Q': 49,
#  'pmkI2GIZ9Qh9LlHjey-w5A': 1,
#  'uHQ2ZRacs1Zhi_38MQz2BQ': 3,
#  'oCFQmDotqcyIYAY1JyKUPg': 13,
#  'Xo4i9b1ytYPa2hbNXP_mYQ': 4,
#  '7GC9fVWKa4a1ZmBGLH6Uww': 75,
#  'l53FUDHRHLg7BQ89KgAtxQ': 37,
#  'c3yJNjz_K--z4CIpR7yhvQ': 15,
#  'WRY-wk7t2u7xxrIwWbQu0w': 9,
#  'DKi8rNg_jTZpVYs5BVVnRw': 2,
#  'htC49ZwXiKNka5cp0GKBfQ': 26,
#  'q0KigjVBtb6dfRjX3QJbsQ': 24,
#  'VcN9i7sPrGSOn4BnpOJ9tQ': 26,
#  'ca2Sa9Enqg2GlWFQ95p8bw': 9,
#  'EP3cGJvYiuOwumerwADplg': 35,
#  'tLrjg5jMmBfnnTs3d61SWw': 5,
#  'k8QnA7UNbe5DBCmYqxYs8Q': 1,
#  'ZzaGa2nsW5bh71N3GOFO2w': 4,
#  'QUTW6GQnEAJSqrzoUJ0m7Q': 3,
#  'dTTbYe3Kniw0KLpNUYinVA': 1,
#  'JkHm-xBNa8KKNvWH5TKk4Q': 2,
#  'nM3vfxr6fcnN_nXdzwbVCw': 27,
#  'ScR4Kp6zM9QYpi7pEE3pVQ': 1,
#  '3Zi1udoY2iT9s8Q3X6tgZQ': 38,
#  'bc8w3CYs70_EgwTxQHVjQA': 1,
#  'p6Os13EIOkUOUK5pzd0-ag': 2,
#  'jdeNI5TTTuM6mj3HTgstRA': 42,
#  'r-zwGpl12La0MQn4Jf-2hw': 3,
#  'NMNiUVcUFLPWjQme5Fo6Dg': 8,
#  'JPdGiAA8qNS-9Re2RN5qVA': 3,
#  'eL2AbD_vXdP57eewFH21lQ': 9,
#  'qyy2X0sjuwcikplzdATfGg': 5,
#  'ru6uX6w_ms7B_Q3U7wMYbQ': 5,
#  'r8xfTpifZ7gP5Cd5CSQaIQ': 4,
#  'C5N_L46b_EYU_0WQJt3iwA': 4,
#  'ykg3-2C-8Vv3K4mVj1iSfA': 12,
#  'ebCOe-Bavz5fYCVL716KIA': 4,
#  'PlYBocPQMxzbDWLGIGAa4g': 1,
#  'V1k7XMUX4qHVUi-3IUYzhA': 4,
#  'gC9JZOzHYxJd8IxUlzoqtw': 1,
#  'CC1INHcQo7eM-SST44UnVA': 3,
#  '9F3ZmyGKIA6ALNWgEq3Log': 12,
#  '2ARM6NFVciTzV21r7p8jiw': 10,
#  'y9YW-BpDACEGytpX3NaeRw': 11,
#  'w225lKHnX3jorkSXWgss0Q': 1,
#  'Sve2h1r-jOyaoGY2GYL0WA': 10,
#  'nGuemQk8wCFyohPz3Z-big': 5,
#  'nEL-_kLeN37CSR9fXFY4zw': 1,
#  '31tjiU793jocP_DKwn1V8A': 6,
#  'z-JC1S58qaW8WNiOzUh_TA': 6,
#  'sbNbxmGNodDJukgSXBFD4Q': 1,
#  'viMBWEgaZ0gSUpre0W8rhA': 1,
#  'MZ2xyaW-hMOUzpUcHAUatA': 2,
#  'JffajLV-Dnn-eGYgdXDxFg': 54,
#  'wysB0lvlJuSBwUAerJqjJQ': 3,
#  'nRWHSp7rtXVPCjHxan_h8A': 1,
#  'z1tNqF5qJRpibGj-9_r9Ew': 15,
#  'Hb49IsEZltm85wLz3uMrmw': 6,
#  'Y1yGvKaf3XzQ-oLu-J4-3Q': 4,
#  'qQns9dP75RNOWOVWI_ZKZw': 31,
#  'LqgGgWi3FLHBViX9tmZ9sw': 62,
#  'xH5ETGmT8IUaPjbwZmj-Ow': 1,
#  '1S7XdhbZWR17Wy4TBsIzaw': 19,
#  'VL3-X2kM2u2Z7dFo-FXVIA': 5,
#  'VChMRGEsIC675BAjnzq4ZQ': 3,
#  '6670GGYK2G11s-D5JQbgzg': 2,
#  'L56wgzkIBP5_zVPHQ9XQCA': 3,
#  '4GdN3itvzmFc_6kib2UzlA': 1,
#  '99Jm9c6QZjvElZznML2Y8A': 3,
#  'u760qQnKAwRkRhq6Fn8yzA': 1,
#  'Q4c-HD4iycZGrAnNK6d0tw': 5,
#  'WxO2x4xGbHfeWfU_MbuzTQ': 3,
#  'k9cMboDc6uqa-6BggMxxaA': 2,
#  'YnuPa08WRFw_VYQsb3rcoA': 1,
#  'DFOHCl7siB7Jt7ggQ8fEyA': 1,
#  'IMeUbv6u0uIIoMFKBOZhtw': 1,
#  'N1Q6HiZvnZHjNU712Gymqw': 31,
#  'QEDVhdE7tK6aQp1WuJY69g': 2,
#  'Cp-PV8rsypbO-xBrQ6KmQg': 32,
#  'XpSZrY_Ym8GGx7SNEd0q9g': 4,
#  'f1EokGAtmy2OChSs1XbETA': 3,
#  'hW2XQMGHy5_TW7dnijZR6Q': 8,
#  'OsYh3jArm6fgozczE85ZeQ': 18,
#  'iC7NVBmkzRl4rKEU5MWS0A': 21,
#  'Ovac_Bws19DOy2_ai3WzeA': 14,
#  'vN25DTdMDr718zMCAgJvQQ': 3,
#  'ddr63wQ7CdByADPnHNr4-w': 2,
#  'MhybZXjI3PrrJ2l9QJ5o2w': 1,
#  'LIWGMn3Yz1LIUZXA-VzOBg': 1,
#  'agNzBnuOmGqfDL2oMBRAYw': 1,
#  'ghcW4xVywnbaAEq5eW2slA': 1,
#  'FyA9xkaXy_cjtYYYnCTY_Q': 1,
#  'uBp2Jmip2qXQ0iWHUDY9sQ': 3,
#  'vUM21g3cPEdSlI89oDttgw': 10,
#  'fnO1oH3N5QMG-PvHA4F-VA': 3,
#  'Pv7DGHzZ-uqIUdOsqPpsVg': 36,
#  'LX3cTVaS8f2UF0Uuafsfug': 56,
#  'LdhwY7eudLlx1KFQQe9GwA': 18,
#  'Vv89iM91KdciCALtg6hJtw': 3,
#  '0TuOVaf4sM11UUbqGRL-4A': 5,
#  '3s0K-1USEkGnA8de9GRrhQ': 8,
#  'BgY9LwHmY8BO_lPI3pNRFQ': 15,
#  '7b07TmlFDFej_r65H2wF6g': 2,
#  'bcZd4ohK6CIT_BOQ0_O53w': 11,
#  'SC_bFYaDgDub7tDjKCvV_g': 5,
#  '9JpnM-xebt0343KkGR_HKQ': 22,
#  'pni4uLN1j4qwh_4dSUPnlQ': 1,
#  '4muLyMlTP1ijRLACBBRcaQ': 3,
#  'C5_Fe8CxYWLlxm44U1yrsQ': 5,
#  'Zkn45PKSC3Lj-o_ZnK35yw': 17,
#  'YEp3lrsXDGDbLT3cFRHT7g': 12,
#  'TL46g36OKxmgSDYRFJdPRg': 13,
#  'I3YhFIXT3TlNBd5DmeZGXQ': 3,
#  '4E_nPWw89FLFHdNsEgMH-g': 15,
#  'joIzw_aUiNvBTuGoytrH7g': 109,
#  'dn8OpAemsZCUzbSwtulNHw': 2,
#  'ROr4DQ-gxlfUKmiDC-qSEQ': 17,
#  'syF-6VzPdjmCXbTye6N9Eg': 3,
#  'AeucYo8J-rZjcq09Wuqsjw': 38,
#  'N-D-d1Z4UybdlkK1HxlNPA': 14,
#  '7P9okhRRYG0hz02Fk7tRMw': 5,
#  'UWhxz-hO6cYy1Y2pLowrJQ': 4,
#  'rO3WEI9L-_deUR9-JHuNQw': 16,
#  '3Jw-rYwJEz6jSqPgVVmmhA': 48,
#  'gc4rNAgbGydNMAPJ85FZag': 6,
#  'OwgqvIcUSTwFJueBX9JmcQ': 1,
#  'cWg07SD9-PnDUglqtS5owg': 16,
#  'k8vE4MWAvcAYjQ7EyZGkug': 3,
#  'hedOECpUoqK0wkodLk-rqg': 4,
#  '_bYIJdwBzZhHGcDQjiFeEQ': 2,
#  '3gIfcQq5KxAegwCPXc83cQ': 79,
#  'rTMsw1YYYQhzrXX9ovtLJw': 2,
#  'D5I9x6Uun4-N37vCm30Mzg': 3,
#  'wapnZrMhivxyy0djBaHoeg': 15,
#  'mqyH3CqjMufsm5FccDrjLA': 12,
#  'khPlizt3ava1xkbtAxHQnw': 15,
#  'kffxYQVQsEpF1DVlQlcGCg': 23,
#  'YEVokKX9G9PgHJ_gK4gO_g': 4,
#  'AMTubqx4AT8ZnrFvvJng2w': 7,
#  'M6oU3OBf_E6gqlfkLGlStQ': 34,
#  'RNSGaQSkC56tGPfKt9lHjQ': 25,
#  'fIvDzLhs-cXbTKWp8P3eIA': 2,
#  'E_1N6H102rr1YdZAakDLYg': 2,
#  'NsIoM2PlaL28E-jbrs4Zlw': 19,
#  'sPEFql7fLp0oouFxnooGpQ': 11,
#  'uj2fHfOZ8_tR5kFGl9sV0Q': 1,
#  'rC3JBdYGn4l7opz5tSFs9g': 3,
#  'Ts6UNH4LQp4YIwATf-cqnw': 3,
#  'DZ7NafMn4ACDLcdCiWlllA': 7,
#  'KvVxMBkrcOHW3DkdxUsquQ': 5,
#  'r2D6DUDgN2CCDVtqranHTg': 1,
#  'uL8JCYexqWNs2Ewg4Cimiw': 1,
#  'e8xrkMtbKJTq33PvPQW37A': 2,
#  'cHnlIFP5WwJRer7_C2NUng': 26,
#  'aQ4wSvsatTj1_iW_YXxHJQ': 2,
#  'QnIm5uXIvBQ8k4FGVSu3CQ': 1,
#  'OqeEFFbXGi6KGg9UeN6AQg': 2,
#  '87xBol0dUS8cWao8F-8P9w': 3,
#  'wEMn5U0mlTp3Td5n2ZgwKQ': 2,
#  'Uxnqej_rEAj-jUOXdk1Kxw': 4,
#  'rR5W8Bj-IGu6sw1_1v4m7g': 14,
#  'nWouNfZD3Pw08RYizxkqcA': 39,
#  'uZbTb-u-GVjTa2gtQfry5g': 99,
#  '6ts41fCsDKHbFZaKOMNmVQ': 12,
#  '72OdAJ2eQYecT91OdJXyfQ': 2,
#  '8GccAq9PTpIWlp0gnCHoRQ': 1,
#  '2LdmDvRyrXgFsVL1KoRfRA': 1,
#  'amv1I9D-4LaOvmL9fVa5sA': 6,
#  'L4tR-pVG5rJMxp_ldxJLKA': 5,
#  'mSuXQZu5NsKXRPW81Llntg': 1,
#  'SJKCDS0LfQelLR_fHRlkJA': 3,
#  '0ef9ECBuv5gghvcPxTI0Gw': 1,
#  '6aLrBqbTXRRQLmMW5RHVJw': 1,
#  'd2RAl63RTdfZF7kcuKcj-g': 9,
#  'IjhG-oFCGvOjP8kxoMZx0w': 6,
#  'anTtulQ9G2b3SipCEwGVHg': 2,
#  'lz6V_bpLpPI1-gxUZJU9Lg': 4,
#  'i_dXLt7xSBQM8OGEjnTdlw': 3,
#  'jYWI9qJFCd1hDwF_dihPhg': 13,
#  '4hR-tE1PYvp7Go5a8s8pmw': 8,
#  'eBwBjylS66qPcHs2_ajLag': 18,
#  '6uNeagh9ljbwV8XRUn_cYA': 3,
#  'UHOFZkgIvb8sn3RSPMXMSQ': 2,
#  'tpOgdsqWcrlFyQSrRIua-g': 11,
#  'ASenO-NcZyEoJJw_aO7C7A': 5,
#  'qa05pUVNapADHZXpHMPMeA': 55,
#  '6G8vLJUi1Ees2qC3RGA3Nw': 19,
#  '7u3eL3IodZLq4a1ORGJmrQ': 7,
#  '23zT_daU4O5VcFnajw8MTg': 2,
#  'B8HTR0tC1NFe4yAuUV3tGw': 5,
#  'io5b3aooPSgC0gFpSSrqNg': 2,
#  'GuRU8N7gKPNBnWCuUrLOGw': 1,
#  '1vIg1iRDdx8RokPAFNkFEw': 2,
#  'jnMII2mt0V6AM4_oMECyIQ': 4,
#  'YMB29SPB8Z_a2be4O5gxOg': 37,
#  'n0bn_DJxCj2m9y5AMhnA1g': 2,
#  's1e7gVzxaC8uryJVordhvQ': 1,
#  'LRblz3w7ngMUnbDWZzB_Hw': 1,
#  'Zof_qo5X5tRQXvkuuR1RzA': 4,
#  'OvGwAmRJnUWBx9cy_bn5Qw': 2,
#  'Ks5lPe_E14_-GheoA1A3UQ': 7,
#  'sKXvBM91tMQZTS4bDsyZcg': 4,
#  '2EJbfAHmwxm_G6800s1nLw': 1,
#  'o3FDn0YCRJpGHMPrpuUUpg': 12,
#  'SSUp9ZVTgaxQ2SweskkO0g': 2,
#  'zNboC5RhzoDLh-CffdIMzA': 1,
#  'U3uT-Phb8iL2iuZpAROZlg': 1,
#  'WnrKtdSeJhh_H1XM3oOXgg': 1,
#  'jXGaZVodhyHZ_5r7GzxrUg': 4,
#  'FmBpiDp6KMjlP3mKKp8vGA': 2,
#  'ehtcnF3Ebvq23p107LcsuA': 1,
#  'OsD0cwqmg4JHheV7O17UDg': 1,
#  '6G_83_F0CQ9XJZdYdeE7Hg': 2,
#  'h3aJjV87gtjgVvxiopsrjw': 2,
#  'ltGh04bjEBhwItWVVG7UJg': 6,
#  'HHlIOuuImgBq7Gbn5smaRA': 4,
#  'uGsL74xWb-vDbXCn8u1LkA': 1,
#  'APLIPfq1Rf8QyhHHk2uAyA': 44,
#  'iqP9cGJIVakQfaW3QL3WFA': 1,
#  'O-Offow2UVaab04Wwv9g-w': 3,
#  '77UjgOU5vayzFUCFUhykgQ': 8,
#  'BaHlhZ4dUO1AUY87ZXY6Tg': 5,
#  'XMEBJp8mmpz3vsSkvg9T9Q': 18,
#  'hq0WUfau1Mh3GyHn8oVdNQ': 9,
#  'FPWwCD73C0PlRdDfJ6Tuqw': 10,
#  'zt7Yfeld6yR_bD4EKaOMjQ': 2,
#  'KAlrXgWYcNrwoQOvnGtgtg': 3,
#  '_N-DeS909pOyryxC0mMAjw': 7,
#  'K_ZAORjuL80YUhV1HC4PGQ': 1,
#  'nFnMOEJPy98wdEKAVzFs3w': 2,
#  '4D-8OaHKOJmNZzgXSqXjJQ': 2,
#  'BXRWIUONLsTvpG-ESWLEBQ': 2,
#  '1RzVTIr6nxAwPV7RB7-U0Q': 2,
#  'GksCsVyXSABI9DNpJbFpTw': 1,
#  'AivhZeFM9EivrtQTc0iz_A': 2,
#  'NAfU5nspEdZW1CBge0rxKw': 1,
#  'tMR534A8JM8lc2GWRQ1hcw': 1,
#  'obZR7Hn_XTXPOtnynW4H5w': 1,
#  '7Pyi-M7MfO3R2PHTuVY0TA': 3,
#  'gw2sxzQrSTo6NpMSp_gVNQ': 1,
#  '3xVwlgww4Pw5wc_twrfOwA': 19,
#  '_4lqpCYCqOQzbB6xQGGhrQ': 33,
#  'mJYDA1COTEzU6LI-sZIgsw': 1,
#  'RzpxUogiBp00GtyeMAQ8GA': 2,
#  'SfDerUF2N2Hx9D84VrXpug': 5,
#  'fhV21-QB6n402-J9vR-7cQ': 2,
#  'ZWgo8S-QugczbH2BN2GL6w': 2,
#  'chECojA5tp0NzBxMgQIfgQ': 10,
#  'JxytDdximBz9C1phOrd7pQ': 4,
#  'jopndPrv-H5KW2CfScnw9A': 20,
#  'cTQOEKBVSqrsyVl2Ssyolg': 2,
#  'gJEJg1fPVDPnkdcVFbVlBQ': 1,
#  'p4SNP70HYUpK_wXhRpIcFQ': 9,
#  'VV3UzNU2D5OkDpwgxtoj7w': 5,
#  'aCktH-ZuS2KwaScos8xNSA': 2,
#  'TWf1hVrosPKBgFHkoujoXQ': 12,
#  'J9u2d1P-nr937LGlZ3wmHQ': 1,
#  '8ZepxUnCcLRZ0NAE-YVy7g': 3,
#  'rjsx6_pSqwl0zuiwa_tI2g': 9,
#  'v721TYO7DMiU5Dfd8tOnmQ': 1,
#  'qYOtHoVCMkdmh73wvUohIA': 3,
#  'kq5Pdsy8Znyh9KEkxWT_QA': 8,
#  'e6iM8wQzEv7bb8jXVOQjQA': 7,
#  'jXp0eFDh_LNO8JfcGlV3pw': 10,
#  'mSGCYGJB3TIjE92zVDmo0g': 2,
#  'lViWWAZLMGz_TMKfrLon-w': 3,
#  'FxxYCRPcpd__yhRRmmtyMQ': 4,
#  'AFo7Qm-C4qspc5uDUUKkdQ': 1,
#  'jAVKFq7iAE_IQYdRT--hiA': 1,
#  'dWwaTl_Fmvl8djX0bVVTMQ': 17,
#  '9EVx_OlZwFmen6KmHHIGpQ': 1,
#  'lTyX2QAWiGda3HQLZkS9xw': 3,
#  'QfRmDp4obVNSfFneMfFMNQ': 8,
#  'VXUIEbW9_xbCqs12EYD8QA': 9,
#  '_LGc_12v8LaaOdz0mdYkXQ': 3,
#  '5lq4LkrviYgQ4LJNsBYHcA': 8,
#  'UqRsXvlnI3ioAY6DxJsRcA': 3,
#  'z1c8uQv7tfgrP4-sVggbTA': 1,
#  'UfPzhC27R744fh2GWvdkkQ': 6,
#  'HHqdz6xvmz3c_XQV6MPLkA': 2,
#  'pGaRAiCRfGs715VbgXf-yg': 1,
#  '1uwqR1r9nMDgI6RZT_bL2w': 5,
#  'q9BKnyqR9roAsWnxAIaWVA': 1,
#  'lCq45LZbHpZXD72GJ7YOXQ': 1,
#  'aU4fCjkwP6Z8aR5azt9pSQ': 14,
#  'A8e50wVP7xcz1sWOE6gEbQ': 2,
#  'uTyIIbOvXH_XZw7OEiTiNg': 6,
#  'DIhY93zwQZy_RUg64t77SQ': 8,
#  'JOG-4G4e8ae3lx_szHtR8g': 1,
#  '5Ht4W7Vu2j6E31UN6Y2zww': 1,
#  '9wdAOSpQU2Kmll1V5uAgSg': 1,
#  'JgDkCER12uiv4lbpmkZ9VA': 22,
#  '0b_ehtfJXDNSBJMW1hSQ_A': 1,
#  'PXlvgzU25CBGA0JHzzpmOQ': 10,
#  'FB5y4CbqJzX3r7zELc7SqA': 3,
#  'infC_5J8sA4NiL_QBJpWag': 8,
#  'AangeOfIV7Mtviy__ht6xA': 1,
#  'mUUy72UfqmFj_krWclKELw': 5,
#  'FL1xj5qKFZkU5GXVBj5TUA': 13,
#  'DeEl8Wv1AF8oFTBKazp5Mg': 1,
#  '4UUIpbOTPmu43wuC2aSGkg': 2,
#  'GhCA6N7sRYZHBr5QKAcCWg': 3,
#  'dgX04RZOxtoipH9Dwf3MXQ': 2,
#  'ioTLeBk0Kw7H95g-rtzXrQ': 5,
#  'JkHLxF7VYgfLRQ6DTUSewQ': 1,
#  'PDRWbCZa92irf8mK5X_Kig': 20,
#  'BV8c4QZEzvPWA00ZqJp-jQ': 25,
#  '9yYmdZw5ehjBAVQ187kxXA': 1,
#  'e8ZXaLh79xm9h5OKLavILQ': 3,
#  'PmDHdnS-EkD4mOIsHD-dVQ': 2,
#  'yGs16xQiN3dLo03OQyto8A': 6,
#  'LoSifdxmrOj-a8xcDrRJDw': 7,
#  'XXASa63lj7XotC4e2HZeFQ': 1,
#  'CKqEh7wAUOBw07LXYCQrfw': 3,
#  'i_GGKzPs5t31yJE_HTCp-Q': 10,
#  'lKAr9jH7rfpN8YuOOZyHDw': 2,
#  'mLfjeWUJnNiqHEye3I6qug': 1,
#  'tGZPH2vrrxp20oA3fESE1g': 1,
#  '2bBBL7obIuO5Aiz5gSuVJg': 1,
#  '2TX0Gv0k6ZtEfVyImcvnNQ': 9,
#  '64thrreKpvpjTVLszJd_qA': 1,
#  '7GPWvigPED4hwy0tJqN64Q': 1,
#  'koTB0T-WJWKmu9YS56GxVA': 5,
#  'k5Qp3va9jlWVOuXY_pJDLQ': 6,
#  'mm1-8hxSTbQH9iUAIkML4w': 5,
#  'o2J22OK7xXL-sDPzANxy5g': 4,
#  'N4h_3ZR-7slX_BeaokL7kg': 2,
#  'PuTmcfPDLNUAKo68LmdZOA': 25,
#  'yp90PduP1gD7kgCLWuQg4w': 8,
#  'nZ9XFVETN4hxdK4qPb-T3Q': 3,
#  'C36PV6x0gNdSdy_rV32vbA': 3,
#  'vWCksqJJfYjGGdD-yb9qGA': 27,
#  'j0Nw9lLD8c_jLcY6uSmN_w': 1,
#  'xd0fvWA4yAed6MclXzxBdA': 2,
#  '7C-jyTrOX-iJ-MrSJuh-8A': 20,
#  'b2XPhXPQ41qWysIK6RTsFw': 4,
#  '2bnbXgguLNwvqsfVFaO0Ow': 1,
#  'vQayPl7cix0BFaSiL_t5XQ': 9,
#  'LFFcpdIUCSRpOlII8hWK_A': 1,
#  'OYpsdMcpdCdlkknpgpFMLA': 7,
#  'I-P1v7sRjDLEfVOndp01kA': 11,
#  'JDVbRaxrjJaLX75UQ8Q3Ng': 1,
#  '90a6z--_CUrl84aCzZyPsg': 33,
#  'HMMm7LFFEOoMMonk32mEhg': 9,
#  'Zi9UXJ81qMtzXRZ8mp7PxQ': 3,
#  'mB7533hZM30GIULkWFBfhQ': 2,
#  '04xW5mhSBaCzpjbcf2VSZg': 37,
#  'br7jwXG7TaWC1-vrZxResg': 7,
#  'DU0F18NBXFZ-hsPOmGhzQA': 5,
#  'C6BYesCiITaw_STVT1GI6g': 4,
#  'EXZrHtmzdtDHtH9MPNEhkw': 1,
#  '0ouMuScWJ3GuNtWEmmsziw': 2,
#  'gkpMjWWEDKbiWSWzgubq3w': 2,
#  'gu-us9D4ONg3ZROy4U25AQ': 1,
#  '8URuhYN9feJbzqxm_oVTdQ': 13,
#  'W9ZG5q-QIblXYeHgaPS5Uw': 17,
#  'WESBNCIvswTWh-Ak2uGf4g': 4,
#  '3ch-JeRygCmrXf4mwZ9JTg': 1,
#  'fTo1Nf5hXSZqPC_qkvXlrg': 3,
#  'eDB9tT3eaKJHHjoa2YRJEg': 5,
#  '9VPNlcKsL99FvKtz1r9qJg': 19,
#  'B4JqOYmQHnffRn5JUVpCNQ': 3,
#  'kemtiwLut4qMqSZNXax_Gw': 2,
#  'Fjs6c1PwzY1YbTcuAyubCQ': 3,
#  'MGVbnW9-eYx_DDXmWIpGRw': 2,
#  'RHV73wO2I9djxHJ6g3zbXg': 1,
#  'oVWlHAwQBOqP0TuK6cifIg': 4,
#  'cLYVXtfPdWGYf51hY9O3ow': 1,
#  'QQUlKfw-MZGuOrf-B62wbg': 3,
#  'sjXubsgIJvL9tFIctrK5uw': 16,
#  'QqAL6vvUE_lJbAFSucWysA': 4,
#  'NhbkTLXX2srey5kPtVOAcw': 1,
#  'IFOFRBrl4Cm08xGQjrA7OQ': 2,
#  'H_JsAwjiGEOr_RlZmwfNsA': 37,
#  'jOnE59WV2_CMZiuSPcZfTw': 1,
#  'YoBu4TVcP5YHKOC35NPXQQ': 2,
#  'F9Lvy5LfkeYMF1r_Al-Fxg': 2,
#  'RHX2qpUTOv2usuckZIil8Q': 4,
#  'HR_Lxh2ycv0t745Ohiziew': 8,
#  'ai2W745a8wrLHJr7TY0FCA': 9,
#  '9bfryXyHC9-hZyuibVWQlw': 8,
#  'i4wvVOpvemDoCVs_4UbQlQ': 1,
#  'UrJSPcSii2LyKViKotQ_Kw': 11,
#  '4q4GBS0Uj04ZKAwHGAJzug': 3,
#  'Wn47EMhtvJQZTsfvvcnkJg': 7,
#  '55RWJtlz_5NBl69UbT5U-A': 1,
#  'YMsY5ZZQ5bmTp-c6fkPjmA': 2,
#  'ZUx-B52hGRhmeUDVukmjrg': 4,
#  'baqx7ZJ3GHt47I6dnLmPrA': 1,
#  '7WO1DSyx-0FP0cBkaCISAA': 1,
#  '-2XA34d6OGYEUuzqC7yhBg': 1,
#  '4_YfcfHkCem1onJFkItxjA': 38,
#  'TPj2H2OD4mEyxIjRTbFagw': 21,
#  '45V7-1r79DEG0HbuaKYIlg': 4,
#  'X6GycoLMzQaocXBANVnB4Q': 4,
#  'Ib8kGCGfUqubl0u2NNLiuQ': 3,
#  '3LmlnHoIFMx0M5j97cJFGQ': 2,
#  'r8nJMwYV5rxutGgm1_QtpA': 1,
#  'clTYUJCL-rHnVIS2WePRwA': 6,
#  'ePduC-tSwrMQRjKI4Suh7Q': 31,
#  '8T0evnkvRaTomru7ghPGeg': 2,
#  '9eeqmxfVfAT4oyA4y2WcNg': 2,
#  'vkH1XXs1GMwIKG4W-xD6lA': 2,
#  'h9FvuiV-YcvrAYBQhdSoEQ': 6,
#  'XdhfTOCIUkfIua4icmQ8OA': 8,
#  'RvyTTpBLqd8yHomBTW_Kpg': 1,
#  'qT17WVkJi0RvQ4nNPN6NDw': 5,
#  'M-j04kcOanazSntBzoD3ng': 16,
#  'TLj3XaclA7V4ldJ5yNP-9Q': 3,
#  '9YlXXAy6YpADI7v42UwWCg': 3,
#  'Mc25_FATV3pNrELPIL5GOw': 2,
#  '4TA4x0bgELIZ-MCj7PaEVQ': 6,
#  'ayKW9eWwGFcrtJaHcwZUCw': 5,
#  'LmCkhilB78gPm8uIU5nCWQ': 3,
#  'qrYoXi7nj9PqXFFy9p_XPw': 4,
#  'T7QG8ge2ukcfvEosSkg8yA': 1,
#  '49W0lI7hQgYihoIApZLhZA': 1,
#  'K9dSPbFhxbLPNZBTp7uOMg': 4,
#  'Aj5a_ik5B7sgaoJ6Jlj--Q': 1,
#  'sRPhEvUKjtP8V5YRFjkY_A': 2,
#  'eCtkMHrbM8j0R5yabfrRzg': 5,
#  'S-07w5CJfDmEBTNZ9V-ycw': 10,
#  'NzYEA8AZo1KnNjjklUVFzQ': 3,
#  '_-oKt8pfqoQXbRZUi49cSg': 1,
#  'F5OGEH2jk5sA_R4xBp2TPg': 24,
#  'tmTxuDadTVc-KFyhvPuseQ': 2,
#  'Gcq-9mRx7lWkoHD4eo7sXg': 8,
#  'L0t8ESj83JaYTtvq5Si2ew': 2,
#  'Xfv8_MeZi8Dev5hx5-ISwQ': 1,
#  'vzAvkSRois2VMqj_AT7xVA': 3,
#  'vipSiSxRH0fIo9qbfjsHpg': 1,
#  '7vcCMGQHuDmNw3qIjj10Dg': 2,
#  'bEd0_FyH-J1EtRpKefHSUg': 4,
#  'pR6kbWnxhJXQ-pGPcWM-SQ': 1,
#  '5bs9-7Fwjuv4HiQNFVZTEw': 2,
#  'ctZ2rmNfCEUXSmwS90wrYg': 1,
#  'Y7CLCx9zWb8UzZKaIb7QmA': 1,
#  'hV2mUNpH3K5BvOyEwP5a7Q': 1,
#  'V9vStLuNc4aqZO_GK2VTuA': 14,
#  'mECTORoeUYDA5ryP-vy5cw': 3,
#  '0viQKqum79DOfIARWm77Yg': 4,
#  'dHl8uHC2_NN-DiUr_QuOwQ': 1,
#  'KgnQz4WFT892AXmimnP4jg': 13,
#  'bIZiqk9KkgrnVizFB5feLA': 1,
#  'j1kH6G4kj-8NRG4AiktFfg': 1,
#  'ESrdXpT1yF7KZX52bPpnJg': 4,
#  'ftA5q-OQotBkm8cyKvKtBA': 1,
#  'B257Qcn1gRmsAOr4eM7w_Q': 2,
#  'NWEKM2JBpPCtvGtIsRAgMw': 8,
#  'bZFRqP7s0Vszxeu8_IwYow': 7,
#  'F6QsMoJdvtohlbnST-fDyQ': 13,
#  'd95On_QNeQPr01pRNzHa5w': 2,
#  '_bHzW18Vg1gxTMoR1fFZhA': 13,
#  'seIFb7p-2Mz67imAhou7NA': 1,
#  'puY1mdD4w4AwIYPrIyEhWw': 2,
#  'VKiWDL608wBRQtk05ts59g': 3,
#  '4eraKSgRK92ryGuAOBnLgQ': 1,
#  'PeWTVqaIBsMYGOUGFH9yww': 2,
#  'P828sX-WbKmwehgh4xqwYw': 1,
#  'MMeNMCy0RWW4cM04IKZO4Q': 3,
#  'vmZh2hlUeC-18cbg544nyw': 2,
#  'OAhO2G3tOfMpO40UlMqbiA': 10,
#  'lXxoslno8L2b9klBsdThhg': 2,
#  'cQfnnQhGCFzd0P1MsJu21g': 5,
#  'kU7iQDW70gcCVBX9uQVFHA': 12,
#  'qaAmAU9T_t84UDGiBI98sw': 14,
#  'lPaYMDmJbAnv_3pmZH_inw': 30,
#  'CP-IE-zyc2Mv3jlaceElVQ': 36,
#  'e0Rls_7QxkVcFJtUXDaA0A': 3,
#  'ahXmdKsanBCT6ImDa6dFhA': 7,
#  'rSk9gydHUIp32_7emi2VJw': 1,
#  'AOC3bEkZ7pTiXRdz0Tgp9A': 4,
#  '6Jb6ho3Zsu8EX4W7LdaPPg': 6,
#  'mTx0GhWWV6NOAd_crYJw8w': 1,
#  'BRNVGPDi58XPDyxfxX39sg': 11,
#  'VccH0vPIn0ZgkseoRm5r5A': 1,
#  'vF4B6eFdoDmyV_l7MLHMzw': 19,
#  'rL3dPeKDTybG_ct9OCXGAA': 22,
#  'Syc4pbEkL3bbzjO4X4HhQw': 4,
#  'tB-m5XIYxirohhvvaoQw1A': 1,
#  'Zg_M3iwTqOgp-2i6Usyftg': 8,
#  'QhuESGhOQWnKqwlSrISm8A': 17,
#  'o2-JGW-3pru6IK9o33oRJQ': 1,
#  'GeGDZ02UfARKBRl7LqKZuA': 4,
#  'noekNAqLa2L3az5_bnb3zA': 3,
#  'XLHDwNRYynxd8oiyIvk7DQ': 26,
#  '_8eGLKjVpGK_mxwM8mlOgA': 8,
#  'kRbQXbWCjn3lwWyIQD9cXw': 19,
#  'DvrsD8rySf7fmJl2PVn6oQ': 2,
#  'Q_LkJOgIvNHq4v6lEHh_tw': 1,
#  'RoOwAUD8CNZ2uFnR8qC2-A': 1,
#  'ZW6J3hLaTgy7ygZ6V0ZXug': 17,
#  'qJh9SHpaO8H7ltyuJGoldw': 2,
#  'TnJkGewuDhD0Dr6e5f58lQ': 5,
#  '1EThs7Vakny7bGBRQk6x2w': 1,
#  'EhKX4TIsVSpx7U5-iOQh7g': 3,
#  'RCjuKSuPezW6qI3ZKgkncA': 2,
#  'zNq2Xyg399kiAbTg5jBuyw': 1,
#  'rYZeLgKIoyAxhMdL12-wRw': 2,
#  'Wuk-ajsN4e7n1zBLIedQ-A': 3,
#  'CmVxtdhFW707wSEPwAZVRw': 3,
#  'H0nYlvGjMA9szTaqIwTwpg': 12,
#  'Um8eFxZBCxCR4FNGO0DeEA': 7,
#  'Y2R_tlSk4lTHiLXTDsn1rg': 1,
#  'y5TsYk1VTXgbNoYCWw-IPw': 2,
#  'IDHrwv_RCildFvmfWTkj5Q': 2,
#  'GKzWSBv2Dpx3ziMFQ4S0gA': 31,
#  '2h0A-NirfNl2p2SquFWYHQ': 7,
#  'YmwVEGMrVxelz8IB9b-84A': 1,
#  'kE2Dw1sKMeaDOpyZNVQKJQ': 7,
#  'yOSz69afsE04ilUfAckLaA': 1,
#  'l6eB_WbjS_0y2C1MArUiOA': 3,
#  'TtSaKKJ9obIgGTxwr4UK8Q': 10,
#  '0o0VMEJeQY0pAAZ9nxErBA': 26,
#  'q5nFaw9isjD_01PpVAR7hg': 22,
#  'TEGWADXt1VA1832jbVtSqA': 1,
#  'mu2h8COMhAdnoQQ42TUTSg': 1,
#  'AirVzN1BVQBmq5zY0YMNYQ': 12,
#  'mxwQi0rr25dIvHUaCs7EFQ': 4,
#  'ClwvJsIns4ESympKrDaqGQ': 2,
#  '7oMqFG6Su53dtbkVnF80Gg': 9,
#  'GnfhkMo0Y5qDsEOGSpvD7A': 6,
#  'rLtl8ZkDX5vH5nAx9C3q5Q': 55,
#  'PDpWGp4PVts0rxK_h_2ntg': 4,
#  '7HDDL2FWibF3rGOZBH2IHA': 2,
#  'bAuKPiWTMtCoNNcPBGWssA': 5,
#  'JkMOQaMjlBHMqp6gj-hL3w': 27,
#  'F9hl4Dn1Ube3A6NShgfXmw': 2,
#  'UoBfwbXaixelZBghbJ2cSg': 14,
#  'iq46mlqoLmNQzTR1z8oqUA': 14,
#  'NcqFZT7ngEDHSJqRgpV8pg': 1,
#  'WQyk2CwF6Uotflrl4ZEfyg': 3,
#  'fev0iI-XDrteD4SYRKjiUw': 30,
#  'Lp2G664ePG-JFxwXZQtm8Q': 2,
#  'qFZkU_iO6KjU-_5BptIu9A': 7,
#  'p4IrODgI_QmO5M9Q7gdURw': 2,
#  '5sTIqfZr45ZGEjanTXGZCg': 3,
#  'EmloVy5Bgbnv_VFm_oftKw': 1,
#  'ajEWtu_h76FDdEDxwdTWmg': 15,
#  'eA7hkwrrknhxhqs-dOhDYg': 7,
#  'ANs4YACIYYoyAY6D7Xp4Pw': 1,
#  'LA5SlWyJxM76zN7RbL6I0Q': 1,
#  'RknsoxpICgtuuv46uaTpyw': 24,
#  'PNS9z4aFDbfhpIsHCfNvNg': 3,
#  'mDS8rlDOcgRT3PMHGz3tug': 12,
#  'nUGV1dVjO84ZI3nplRbwFQ': 1,
#  'z2aIK__6KMpQBx1czvv8BA': 12,
#  'LUGSw8o04ghJe_-4-X5fbA': 7,
#  'ws6BQnim4x2dqDeW5qyD3Q': 3,
#  'fGi3Kg1FRFurq_2JBfw_Gw': 10,
#  'SW1qky1cct3B_gDcJUIY1Q': 1,
#  'szbTVEtATfn8f9GxbGGO5w': 11,
#  '2MPGdIbaaEdKuW9IpPxHfw': 29,
#  '1-A_PLT-60EZ9MsfbkV9sw': 1,
#  'PBxgmhVs6eW67xgL5sL85A': 3,
#  'kJyR4gT1pfCcNjEY9-YMoQ': 12,
#  'vC-9ROCPBhWuXtMcBNeDiQ': 2,
#  'CaP2S-hF9F_25nz4F36MmQ': 10,
#  'VocJ2eKCB88wgnM5sw-LNg': 4,
#  'WEuIqh8ygm-bH81s8lwD0g': 5,
#  'oIVsVM8H273aoT1JUmsDIg': 4,
#  'XY_bQqhZfyyEi_W5n4kQNg': 3,
#  'q0IW1-twB0WY8UDtvt_zFQ': 1,
#  '9vxUUOoasnu8gtoXRwAhYw': 8,
#  'tVUVDWC-RDaf8GN4-7-iXg': 1,
#  'T46gxPbJMWmlLyr7GxQLyQ': 5,
#  'mfvezpz6ohS0NQk3DZdvqQ': 39,
#  'PWa942b3WoOsr_T1PrZeVQ': 1,
#  'u-yh_ENUSE3Ap4rAmYRw_w': 3,
#  'A_O8wZOsMTPwyeYA4-Rsow': 11,
#  'XgIhw-aWaq_Fx3ZVQGjnuA': 51,
#  'd0wJVf7Gv7v1B-HHYhxZtQ': 5,
#  '7i8MGa7zyWmaQli6o2-29g': 1,
#  'Yw45IPdSZtICxMY0Tnu8sg': 1,
#  'EQ2pm01gowMVsFzjXtWOGQ': 3,
#  '2KyJLMY3jmASmwtnmlBuvw': 2,
#  '4mr5Ys9VKe87c_kgpRbQ0Q': 7,
#  'TVL1e0NHhxAE6PpeXGfTOA': 3,
#  'zGz5NI4sscO4_6YYH-qVtA': 6,
#  'MqKtiMUnd1CdvNKUIlNspA': 8,
#  'CrOoT6cjYJfIAVaxCUEaXg': 1,
#  'I66DLxK1Nk_JthEShOWKUA': 1,
#  '32yCk5GTLAjcxUxvUOhWyA': 1,
#  'BH3nDDQU6OgWrCBjPRcjzg': 2,
#  'ZeQZQY7CrpyxviVBhwveaw': 1,
#  'FbExpUiiAP6NiebgsN8zzw': 6,
#  'A-D1tG2sx5lP0KIRhvO1kw': 3,
#  'Z0P7xigz7h6lPqwO0cn2NA': 1,
#  'ddL_dN4PcqDo_ShTnepIKw': 1,
#  'D6j51VNGUdS6sLCTLfzxTQ': 1,
#  'oSIYpve7KBefY63Dc-jGag': 2,
#  'Kqvfep2mxS10S50FbVDi4Q': 7,
#  'jlr3OBS1_Y3Lqa-H3-FR1g': 2,
#  'mQekDIvOCHR8bPLH7Rpbpg': 2,
#  'Z3c7xGRfeV-uMkSbAzxV9g': 1,
#  '5W-ruHmpkwLyI6LlanHstw': 1,
#  '51-ZrwQODnpIX0dQEshZNw': 6,
#  'xQJY0AAY4yRaUqWUjD_nLQ': 4,
#  'P2vHl_ZzSzeu07W29KsKgg': 2,
#  'xm47wfTVHLq8-72HR5nPmw': 6,
#  'MTu3hVSZkK8nkPhqT2FIDQ': 5,
#  '8gX8VpBo0dnSlKkWIdhIrA': 17,
#  'Kt9NwDONle_mc0QHTud9jw': 1,
#  'kXT3pVtElactR8nFmeLbbg': 9,
#  'E83jZ7j07Hx-RcRiTbA_kg': 4,
#  'hNk9YQNC9vJpEs5swUlbeQ': 7,
#  'mQba83gB018LlGt51r80ZQ': 19,
#  'eWkFFGHQimihdQpFsO_Ffg': 1,
#  'dn9DSDp9CYCRffmL1voq6g': 19,
#  'frm67YsEcoZRU1gIqQQj2A': 6,
#  'cwIZyUzEpsXzz_5VZT4LCQ': 5,
#  'XnoIg-UnpRjxXtuOB1Ev2A': 1,
#  'tueZZgG49lLPMj1gRkM2Ag': 2,
#  'TCEqENMcnIjsBCjlI_Stzg': 10,
#  '4JapGtmN58pZYo1ClbV8qw': 9,
#  'imb8zI2mPdiXSXeRuVntag': 1,
#  'UhgUFf0U0If5KTpcRyF5Zg': 4,
#  'Q77PB7dBeVgRB7TshYFEOQ': 2,
#  'rOpHWQXgXSnAT99-QE0QoA': 2,
#  'XwBwRIFEaWjT25bQew911Q': 1,
#  'CWQOBs0qw58tahumYRBREA': 1,
#  '5MbsgK5qo1BODknrDLN49g': 1,
#  'AdpQcQcRVNZdG_17p4V45Q': 4,
#  '9VF522wucngr7m9wzXa5nw': 2,
#  'tI5iYnvKgfmAWn2dbozMTg': 1,
#  'fbI36KFLubq5adz8lzX3Rg': 1,
#  '0S3xCHTktjXx-1AVf_NQCg': 2,
#  '037gJ6fmcXCW1ajls5tr_Q': 1,
#  'Vh7CdxGFglD0Tgfm0wtCPw': 2,
#  'JnRT9i2d71pY8D8ngzCz9Q': 11,
#  'DwU7KVfebA70AlVtX0iOWw': 15,
#  'iqqMl8LR9KvZlSvxoZwScw': 1,
#  'WQX1Hio90vjGkASKM0v5kA': 6,
#  'Ypz7hxOCnrg8Y8vxHJU-sQ': 20,
#  'h3ZuEh28kwBd2iI5oAFWgg': 1,
#  '8dAAMq8R9o4QlRTqob0E8A': 1,
#  '5S3qIi-EHG634Mx-_mpBQg': 2,
#  '7aQvAhgpdXqkTQEp8b8Szw': 9,
#  'yvWUvG7Gb-_7JcgYQrbDVA': 1,
#  'yyVaDXsgGPw3vl2bv-1R3w': 6,
#  'ZQTN4owdKLm69Ci88zoRUw': 2,
#  'tfYiqaLU5swUfMO9JJp9Dg': 6,
#  's7Tm9oYWqRlBm5ex2OQ1nw': 24,
#  'kYgPm0uUJo7cO94b84qBog': 1,
#  'FgauKBp6w-_8hOY1CRYMoA': 9,
#  'aIAjAU-6NH583EkQ6E9KRw': 19,
#  '1ajv7CEuzebjrv7X-iwTmw': 7,
#  'C0qH4_sIqAXWT59dxEgYKA': 1,
#  'muJAX5QzQTZGb0te0M8JUQ': 2,
#  'CJt9v-cipmczq8zDemJNzw': 1,
#  'DFQ95g3s1oi-VcDZEO2TOA': 1,
#  'Nh1-RLlCU5i0MCH7so6_-g': 1,
#  'c_oAY5TDj8sLfUPvotwHjg': 1,
#  'UPtysDF6cUDUxq2KY-6Dcg': 7,
#  'wHg1YkCzdZq9WBJOTRgxHQ': 10,
#  'kNO6w6EIKo8u6GSykOHBLA': 20,
#  '5j0hoUVgYJTyNshMXgJ4rg': 2,
#  'PiIdsdEd8JrRaMv5aDzSZA': 10,
#  'eAgcqq8MAe1ztS4gqDbpTA': 15,
#  'E0WWNXVze_sfDCbM0oMYvw': 3,
#  'ceKoQX0_IJZ6Lr9-9LGcbA': 26,
#  '3qMUN6NGDq1GWtAJSuvXIQ': 3,
#  'mEimJ0tajMEVZxWqatGpKg': 1,
#  'czMeiY1ehKrm_aZFKAHt-Q': 3,
#  'OnGKdONTxlNYyjX6KXhL0A': 1,
#  'nWw6phGGdMXCctDV_DK3IQ': 1,
#  'jKg43xVpvtcGrJruTbt77A': 6,
#  '_FbZ1gXZL349iiz5D8gz2Q': 6,
#  'JiSt1mjxvz-nTYHk3A2vbg': 4,
#  'p7dvahRPZIWL7T6pFA_0dg': 28,
#  'yNVGe_z9hHxbvpa2Ns2JIg': 4,
#  'DLMtzSl1Z9-0LCzsvs4Qcw': 1,
#  'rnV_UEaLHRH_WFbJQmDwWg': 2,
#  'zqfNAOCE1s_z-21Qs1wdeQ': 1,
#  'oVEbr2jtirosJIenFkWenw': 1,
#  '-Hv0mbeVlO2nB-6cYcfFMg': 2,
#  'KXoRjWfTxPT6LFkOdK6ovQ': 1,
#  'Qe_1COeOqBrCQ4IhLw9Glw': 2,
#  '99soVZ-moXRSatBocoramg': 6,
#  '7zDqr2I0-xpw9HF5Ha54cA': 24,
#  'CEEIQq93JO8aSRx25wir9g': 1,
#  'scxmg3Pu_jjpXSyFWH8-Cg': 12,
#  'V0r_ncTQawicaHAc8TCb4A': 2,
#  'kRH3HttbiNoD-BgomNVVtA': 15,
#  'F1z0661Q9JIOMugXvrL12g': 6,
#  'zwjIdDClpnTqsly-O1Pe7g': 4,
#  'SC7xQZ_7l4dex8JNMHg8SA': 6,
#  'ELzKYmr0EXuCUG-gKgBGpQ': 1,
#  'kTK724Q8b9kZscfGSpsFqw': 1,
#  'nSLrExcVVphiNzvSf5H7vA': 21,
#  '93CVZEe3_HTk_GdDZOHy6A': 1,
#  'TSN_KWBsNc4pAoChdpwi1Q': 1,
#  'jM4qX4eiH9tIG9VUaN2knQ': 5,
#  'KYeLSM3MQpirmHukVV5Iow': 26,
#  'Gzq5CtS6pD4JOKvXNJ4B3Q': 1,
#  'o96C1p5jwTvPlneWfl6miA': 1,
#  'omDaGOFsG1RfqLKcNV1Cug': 3,
#  'LSNWMSAOhZzrSRg2pPxA0Q': 1,
#  'dk4GW5x4DoMmHAAifcI30g': 1,
#  'SGXahHRReksq3m_Zk9V20w': 26,
#  '4rsEkJkwDwuXqcCwvBEFTw': 1,
#  'fzkO1lGkx8MHhT8S4Rbg3w': 10,
#  'd66FhQQZzFDKxklh6t63RA': 5,
#  'zLIV35n1gZ4fg6cGSRqNIA': 11,
#  'gW-ukHucTfVCnFCKKxPJzw': 6,
#  'xgrNgHOs8F5JvEX38IeCJg': 13,
#  'VW1zLVadNrWZgYBCueSFow': 1,
#  'sGL10Y44CVzzKNkLVeHOEQ': 2,
#  '41uQK2oJAmahY0jCrdrl4w': 1,
#  '9UK28WYQvS7aXyNfa_hLCQ': 11,
#  'DMtlC2TpVEimIn0D07HnUA': 6,
#  'YsPqt0gxG60l0cJvHl_ylw': 16,
#  'jqVeTSin5GeRm0ceSg-PBA': 26,
#  '2tPpiBmIZ-yo5HcubK-rjg': 7,
#  'Zm08wcep2F-nRTHRyR8mpw': 8,
#  '8JMsp0Z9N1eWGFuQcQxD0w': 1,
#  'fssanRnCXYXnQIP-zu-71g': 1,
#  'Y5Bu0M1AZzre9CjdlnQNYQ': 1,
#  'F97G9Uy4xlTf8hocE6jS7w': 5,
#  'gfCWt_YncrOmJsU1IQUHbw': 1,
#  'hvgYD6Pmyaa6hS39ymIQBQ': 24,
#  'B6gZizbeBKbjkRkyE0-bxg': 1,
#  'qpplec-ajubZNLQrp8pa0g': 1,
#  'BV37xzLqE0-0dlfGTQdk-Q': 1,
#  'yt6vljLIffAU4WW0-TQwBw': 2,
#  'OMC3DRyGrDbq-oMtdRAH8Q': 27,
#  'Ri8jeh5ZmDF6bXl6Wqshww': 4,
#  '7wPcbtQeZ0ZXdpe_oBYP6Q': 1,
#  'WIGMEKQR1ZDacOewftwudw': 1,
#  'A1yGtQzSfctsJJE1lyPbDQ': 4,
#  'zqnAdayPsak5dbLF2gEvNw': 2,
#  'BfByK8hlWDtlNmJ1G1nCeg': 1,
#  'e44rUPb0ne7hcmEo6MzRGg': 5,
#  'fwIXyM_7HFRfkVQMne79AA': 16,
#  'GRgBu4K7GOb3354esp_xkg': 4,
#  '3wTXuo5-DazxVMRBNKYtFw': 2,
#  'f2P9doabyXDo7JaZ5K7keQ': 4,
#  'FHJUj7EHB9nB2czVOzQX3Q': 12,
#  'w1LjSa5wMexRIQ-82LKWmQ': 11,
#  'qWFYWalunBMpzJvw4WLvgg': 4,
#  'SHcX9hp5RG3-OqsbvissIQ': 6,
#  '7o7vuRkJtnnipRWw3kft8Q': 1,
#  'hAt0i0MarztUAxsooHpZzw': 1,
#  '6gPLoA14w1Pp_ALoQcJoTA': 2,
#  'Yk37VAp452K7FwHWd1rrQw': 25,
#  'zPiEroQrxxyBrHSUAcymBg': 5,
#  'GcjXVxp3jZOHhUNyM2QECA': 2,
#  'qrX3s0BfiHQTH_gmnyysjw': 2,
#  'OuaAwZIX__xEm4u8qrITVQ': 5,
#  'GevDiV1jhZL0Ga-SWyFw9Q': 1,
#  'DBSzlm2QE0nYR4FQpdhAtQ': 2,
#  'mym5tXZoZCbuPCYQzI5Ysg': 40,
#  'X4UIrsuAdUF7ZN0fSdllmQ': 1,
#  'WPIaXxFxKbzQR0nF8qLGKQ': 2,
#  'zMLcLRQVs5Ms4YyE1IbKcw': 1,
#  'xdhu_CZVomaGPD2qB0IQXw': 21,
#  'Ke9WsSOUOdQaTRwaYibYpQ': 3,
#  'NPoOEAPspruMOik-9sKQtQ': 1,
#  'bazh3LiYydXe3hvx3bF0Cw': 4,
#  '2qKgObPOV1kDl6U08Mjxyg': 7,
#  '0mwGMnMvgvKd11do4u5J3Q': 6,
#  'tTa7FOsuzCMJNyM9d4Riew': 6,
#  'ixgYqRHucl21_3-qtPcVoA': 6,
#  'YBtz3DqUwLHXkAV_1L8AgQ': 2,
#  'RxjMkVg0oJSW9ryGbu5fBg': 1,
#  'UIHT5FjnQu99trc8mueQEg': 2,
#  'ofQpgTzPos-L5ZS_mP4qmA': 3,
#  'NnX4Pq_pibIt_1GSi-fx1w': 1,
#  'k0gCvAMZIM7vAX1s8oqdHQ': 2,
#  '9qCPmT6ovJjxL4tJB4ANCg': 64,
#  'wz5bTn4OyandnytIe_hOpA': 5,
#  'LHQ2fuC2RDS-Md_dN2O1IQ': 25,
#  'mLUPkvjsKFsafrCG-MtS7w': 4,
#  'p3QX1ZoFOCrin4ojNOVkBg': 6,
#  'tiyg_cQaPdUuSG95Xpi_sA': 26,
#  'PnEAXZ7WyJMYBr9IIulh5Q': 35,
#  '17PPxx8RxjOUD_nQZ1aHEw': 14,
#  'eYoB6mEOCkraWM2vhYikvQ': 2,
#  'cVUJrTgmJ1j7XepKv1fcng': 1,
#  'MKUv9aV4Aq6fmNeFHQjqPQ': 1,
#  'zHH2Iz49wCZYYDLBTv0YOg': 15,
#  'RRTraCQw77EU4yZh0BBTag': 8,
#  'NqeD28GGg1Wdj9BfaHqr4g': 3,
#  'p7VF1Q2aW9HmwdHhKq8hOQ': 1,
#  'WLowOhyzS0TNUemAwEryBQ': 3,
#  '51-53fVvMVBTwQQaUZSozg': 1,
#  'lzzQ-pSFsP00aIH3bZgbAQ': 13,
#  'CEkNGnUQWGhQN60XD4E4Iw': 9,
#  'Hkx9AvnmY_aFXb_mEAS6sQ': 5,
#  'qf2H6esJYrNf6XMCcGLZSw': 4,
#  '3rZANqOuujtsbAfyGABVbg': 1,
#  '5ATM5m3jeXk7_tUgHyxprQ': 7,
#  'l4Bn7UpQMk4BgUoRjUcRfA': 1,
#  '55ecDCpJIXzTWjEzMQ11Vg': 3,
#  '1xFAHoJQZLfStQF6kU4dCw': 1,
#  'Pv4WfS5ix6MAZHAeX-37YA': 3,
#  'sgcHJp8DhSJ8JOFqPSOcNg': 1,
#  '-9mljS0O9mwdOnGv-Oea3Q': 14,
#  'kpdpcrEauxA2bhg-f05W-w': 10,
#  'izQhXnfoP2vPeBtZ2rLU7Q': 1,
#  'ZZ5hV2jcxchiZo6C9AXq_Q': 6,
#  'RbCRHWZotVygDGy1wF6wHA': 8,
#  'TNUX-baP2gvFDajjErgsFw': 4,
#  'l81ILmOhky5bG7o4r3rkhQ': 28,
#  'Y7KS04okqSFAbg1NyImHkQ': 8,
#  'GpDsB_pSKS8nKOlXQXpifA': 1,
#  'vNTHCRZppCQvx-Rsha9U3Q': 2,
#  'vIBrfx6z6wvUFN5IJDLNyg': 4,
#  'kGELmMMIPh0DWnfJalYnIQ': 1,
#  '5wN78N4K0a39C-uPzPmxDw': 3,
#  '3E9XM4pk8APBYPUiI0X05w': 1,
#  'M_C8-rexcexmn2zxwMmp-Q': 5,
#  'yGq213PmiwYSYrhDLPWTSQ': 9,
#  'ygZTPe52ZhK9jOBzS8GQ8g': 6,
#  'toD5fpe7--5ljkAz1ee-cw': 4,
#  'pvdXGtu6sAPDJiCIhfVBDQ': 2,
#  'ehhIzy0QaQ9B-V4VVMgYmQ': 1,
#  'LofguX32B2ewP4FUay2yNQ': 3,
#  'WUG7SjK9WtfU-3Y2Ua-XJg': 7,
#  '_Uq8LfC6X3UJoTurlbiUrA': 1,
#  'wRRVIAIo8AbdayfvWky7jg': 3,
#  'N69-RgMXqRaZbIBbx2eH2w': 2,
#  'ITBs8txD0Zu-YuxXCGqokA': 7,
#  'IGkoathSlJmIOBDGo9vUZg': 23,
#  'fAiVqZv7P_oc5CzGMX_G9w': 8,
#  'ZTF84I4I5x4TBpdoWwLEmg': 1,
#  '3miOUpoAr-NW7nGceQkYYg': 3,
#  'V60Rzx_X6pgcrWJLxgL94A': 4,
#  'wJp8U2qXl_jYUgyW9thjGA': 3,
#  'cebfUwMZxY30pgjiBLw6xA': 3,
#  'L3XWX_dd8_pYnRSMdppjDg': 15,
#  'eiA073MhHpCdwBq8u_luZA': 13,
#  'uptgzZkEm4ytmHuZKBtnhA': 3,
#  'AM2X1tso9b62GhMobfTHAw': 3,
#  'nLXfL00a9nSjB7T_OqKscw': 1,
#  '_wyCFNqRGkS3A0EmGCUNJQ': 1,
#  'QJcLiT1zTJMzrsXWi5RgOQ': 11,
#  'Zyd78OiKPAqaMSC6OWLb6w': 3,
#  'ef7eJrSr7chDjDth0-k2HQ': 5,
#  'pQ6ij6cOBRB3yJGHbVZHUQ': 1,
#  'aJfAJPoynVj-CBLGaXE22A': 5,
#  'Qgc_li9aTDxw5nsuWwqi4Q': 3,
#  'ND95DgvN7ba8MabfXE3lsw': 1,
#  'ukA4tAsH05itDYqhl7qBMw': 9,
#  'gsyguOgT2Dnjw-OYw14XDw': 11,
#  '2CdbmUXg7kkmbJ1XSDrY-A': 1,
#  '11WMiRoB2sQxo61aJdSg6Q': 11,
#  'QocwkeVyChF2JoP_zKH8Fw': 1,
#  'MMgHZwm4rj8W1scW4cEq5w': 1,
#  'QiR2X306Yzd9fuJdKDhkGg': 4,
#  'vUn91MER1jV-jT4crd3pOg': 6,
#  'BjwXX-sChcjx2E55B_7rXg': 5,
#  'tL_QF_iIGoaPd-otIGa22A': 1,
#  'sgANmBtbAr1n99zlNzU99g': 2,
#  'W5Pd_GmMem2LdHZkoxQCtw': 5,
#  'AdVBY7Ow_ICQLfVEbf_nTw': 9,
#  'zLDgSR1q44fyLRi3Ea0Oqw': 1,
#  'He939GwJc3_CGCKST5Bw_A': 1,
#  '7r5Sm4qXSeSNXAVGm9CvyA': 1,
#  '0n2jq7LIPQOzs74kPLCDng': 1,
#  'RHLKZQWKlfraZcFNjJYxpQ': 7,
#  '7MJJ4dacV5wzslKT3izK8Q': 11,
#  'lczLjHO7zIhrmSlOXI3ohg': 17,
#  'YJ69qGzOvGYmxkjbQjAejQ': 2,
#  'pJ3kMwJQJsSZmewt_wzPPg': 5,
#  'QMtB_nKKh9Z6OEFHE6b8Kw': 2,
#  '_8o_CVDQNWx3QluULdaTdQ': 4,
#  'q7srymiZYDicJC9wEUU4kQ': 1,
#  'FbXYzo-QVDr65QpVjndqiQ': 4,
#  'qsRNxnsTbVL1ea83m-jY4Q': 4,
#  'iPhoJlwisUKGGrA0QNmYMw': 4,
#  'MMCiQSRLdhyUzkHyksST_w': 4,
#  'zmPF5EwnljusywJ5sP3QtQ': 1,
#  'TJ-Y-53ofI02KG4W2fbmkg': 1,
#  'k_qZ47wApoqNwl7uNiiOBA': 3,
#  '2Zv2Mw3Mvs_a5KO8U17yiQ': 1,
#  'E-Bd5r6Z3zMGA75_D4IRKw': 3,
#  'j-aruJbrUGLP4ZwhQfDJHw': 3,
#  'DYC9uqPYAwI_q9J9RknWvg': 13,
#  'KuPscbI0KPxudSMPZIcrCA': 11,
#  '8dbRf1UsWp2ktXHZ6Zv06w': 42,
#  'ODW4e78LfvY5Ch4s1kzzjw': 6,
#  'GuUQfQXqsN0MIGK4Lxvsjw': 16,
#  'fEAfppON9koHRyOOBqdS8w': 5,
#  'ast7yCfvhIwaD53OFSXoag': 12,
#  'bFVetbys5Z74h1fcihmvOw': 6,
#  'odaj8Gm4jc7lF20WoZ8RZg': 3,
#  'XDVABSG5JRXry3Dm45vnyA': 11,
#  'MWIfyGWBijcFJ-3JS1hWnw': 1,
#  'lh1-4Sp3InwVLeKrEw0t4w': 7,
#  'cCNucgcprU1pEr_TH5qfaw': 14,
#  'qwu5B9anH4AlEtau0K-6aQ': 3,
#  'IXn7pcVEnJUMlJExYdWPQw': 2,
#  'Zwtx7FLZcK5F2P0-Tz8mHg': 18,
#  'Wgvq9BZwHLGY4jBqvJa8_g': 6,
#  '0lxf4v5NuJ1U6Bk7SGAJ5w': 27,
#  'EoTooNBcxu0Hy0-XeZI8aw': 13,
#  'gUr8qs00wFAk851yHMlgRQ': 2,
#  '0zsGYi4ITkMEUdE8Zl5b6g': 1,
#  'kxIzasUoiNzZKAV_i_iYAQ': 1,
#  'NsVvJ16TMIx5_-GwugAPgA': 4,
#  '79LOudEmAcxSYVA1SF5Ayg': 9,
#  'ilf7UPi_14f-rDsbtlDZvw': 3,
#  'W50T5WVx04EcAaE8GD3RyQ': 2,
#  'jgYtI5zHyIiztN1K-qwWMg': 2,
#  'yPPFHBcY1XQwpZbkSA8A7w': 1,
#  'kG8jkVFgOAOq6Ht6RvAjEQ': 28,
#  'fPHLPrymsyb6WSFFKoMrTQ': 28,
#  'kacOkLRg_lcNA_wPE4bb1Q': 1,
#  'IO3AsR6cdMto7VCwfPzf2w': 62,
#  'Ab6te7czFqcMEJemHcyxsg': 1,
#  '_AuFTKgNYxqNFPyZMeA0qA': 1,
#  'usyCze4iT4H8v3Q8Y7-XLA': 1,
#  'Sr-wB9G8KflQjbAS8Q3HQg': 5,
#  'iwZ_7QuZ1tzT6pIZmOlDQg': 33,
#  'K_gNqlirV0kppqCGnfGiOQ': 2,
#  'T5mD6ggC7fh48QgXR0LevA': 16,
#  'O758lrR1X2zI-ySeyjdr6A': 4,
#  'hY9auEfm3Bdrdrwm8NlpuQ': 1,
#  'G47wUKM3bGfJOg9u3j7ZmA': 1,
#  'qR09EUhlR6g_NU6u5gbI8A': 4,
#  '01nTwhHBaw8AHjQDb7JGBw': 4,
#  'RsHIBC5MLxEqKoKEIGe4CQ': 1,
#  'fwzW24Yx842aUri7hHtRFw': 1,
#  'hno-5CTo24tD9YRdglAZ2g': 9,
#  '1ku7MeWxNp9F1tD7au5SGQ': 2,
#  'pt8KIaIl6R9bcvBaDsOusw': 1,
#  'YavFbDG7DUOTXJBLxpq97A': 4,
#  'J76z7gzmpM9B766vmRRukA': 1,
#  'MUHoBFzwRoXpCpgYSN8KRA': 2,
#  'gW3DYv-sOMtVMefnlUJcyA': 1,
#  '2OLdiDZNdrPkdjp1WmW0-w': 5,
#  'euEN9CF87grHHuMY3WyrfA': 2,
#  'wy8Yd_vCWDjiz9rMo4HfqA': 5,
#  'LXWAXIeYFIdgd2JVPF-9qA': 25,
#  'AMKiaeevcw1k75yeRgNAxg': 5,
#  'FFzadNTcO4mwRSELjBq9Cw': 4,
#  'LoYy8ruCxPZZPF78_Bu2eQ': 4,
#  '6lJK2VDBJWY2JSLOf7JRiQ': 1,
#  'udzY22a6foBOcsU7_7nIPA': 8,
#  ...}

# %%
countlist_outliers = list(exactive.values())
templist = countlist_outliers

# %%
len(templist)
# Out:
# 12546

# %%
uids30 = []
for uid in exactive.keys():
    if exactive[uid] >= 30:
        uids30.append(uid)

# %%
for ud in df3['user_id']:
    if ud in uids30:
        df3 = df3.drop(df3[df3.user_id == ud].index)

# %%
xlist = []
for i in range(0,len(countlist_outliers)):
    if countlist_outliers[i] < 30:
        xlist.append(countlist_outliers[i])

# %%
len(xlist)
# Out:
# 12482

# %%
df5 = pd.DataFrame({'count1': templist})
df6 = pd.DataFrame({'count2':xlist })
df7 = df5.merge(df6,how='left', left_on='count1', right_on='count2')
df7.head()
# Out:
#    count1  count2
# 0       2     2.0
# 1       2     2.0
# 2       2     2.0
# 3       2     2.0
# 4       2     2.0

# %%
df7.boxplot()
# Out:
# <AxesSubplot:>

# %%
len(list(df6.count2))
# Out:
# 12482

# %% [markdown]
# # Q3. Training a LinearRegression model on the data output from Q2.2.

# %% [markdown]
# ### Q3.1 How to build a linear regression model on a subset of the data, using the `useful` column as the input variable and the `stars` column as the output variable. Split the data into a training set and a test set, with 70% of the data used for training. The random_state is set to 42.

# %%
# your code and solutions

# %%
df3.head()
# Out:
#   business_categories business_city             business_id        date  \
# 0         Restaurants         Tempe  6oRAC4uyJCsJl1X0WZpVSA   14/6/2012
# 2          Automotive      Glendale  rxQ2PIjhAx6dgAqUalf99Q    9/9/2012
# 3         Restaurants         Tempe  EC9WB-iVjd28B6R6KIZ8TA    4/8/2010
# 4              Cinema         Tempe  LDJhwZN14AZOJyHjg2lkRw  13/12/2011
# 5        Coffee & Tea         Tempe  o5x6DF0KK1OBsiUOx2gavg    4/2/2010
#
#    stars                                               text  useful  \
# 0    4.0  love the gyro plate. Rice is so good and I als...     1.0
# 2    5.0  Never having dealt with a Discount Tire in Pho...     0.0
# 3    4.0  Cliff notes\n- Cheap: $1-2/plate\n- Fast: It's...     0.0
# 4    4.0  We got passes for the preview of Mission Impos...     0.0
# 5    4.0  This would most certainly be "my" coffee shop ...     0.0
#
#                   user_id
# 0  0hT2KtfLiobPvh6cDC8JQg
# 2  HLbhD2OyiMCUDRR4c1iXaw
# 3  jdoGEEy5s-5L1O_lNzEi2g
# 4  Mb0psF4WQF7gZSuZafVr-g
# 5  xw77viWz_BbmyntxoBVH4A

# %%
x = df3[['useful']]
y = df3[['stars']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = 42,test_size = 0.3,shuffle = True)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
print(model.coef_)
print(model.intercept_)
# Out:
# [[-0.07799]]
# [3.80422854]

# %%
predictions = model.predict(x_test)

plt.scatter(x_test, predictions)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - useful
# Feature names seen at fit time, yet now missing:
# - business_review_count
#
#   warnings.warn(message, FutureWarning)

# %%
plt.hist(y_test - predictions)
# Out:
# (array([ 720.,    0.,  819.,   22., 1215.,  123., 1489., 1596.,    0.,
#         2858.]),
#  array([-2.80422854, -2.36523354, -1.92623854, -1.48724354, -1.04824854,
#         -0.60925354, -0.17025854,  0.26873646,  0.70773146,  1.14672645,
#          1.58572145]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn import metrics
metrics.mean_squared_error(y_test, predictions)
# Out:
# 1.5098839615887112

# %% [markdown]
# ### Q3.2 Assuming that the number of reviews a business has received  `business_review_count`  can greatly influence the average rating that the business has received. Now, we create the relevant variable to the data, and do the LinearRegression again to the `stars`.

# %%
df3.head()
# Out:
#   business_categories business_city             business_id        date  \
# 0         Restaurants         Tempe  6oRAC4uyJCsJl1X0WZpVSA   14/6/2012
# 2          Automotive      Glendale  rxQ2PIjhAx6dgAqUalf99Q    9/9/2012
# 3         Restaurants         Tempe  EC9WB-iVjd28B6R6KIZ8TA    4/8/2010
# 4              Cinema         Tempe  LDJhwZN14AZOJyHjg2lkRw  13/12/2011
# 5        Coffee & Tea         Tempe  o5x6DF0KK1OBsiUOx2gavg    4/2/2010
#
#    stars                                               text  useful  \
# 0    4.0  love the gyro plate. Rice is so good and I als...     1.0
# 2    5.0  Never having dealt with a Discount Tire in Pho...     0.0
# 3    4.0  Cliff notes\n- Cheap: $1-2/plate\n- Fast: It's...     0.0
# 4    4.0  We got passes for the preview of Mission Impos...     0.0
# 5    4.0  This would most certainly be "my" coffee shop ...     0.0
#
#                   user_id
# 0  0hT2KtfLiobPvh6cDC8JQg
# 2  HLbhD2OyiMCUDRR4c1iXaw
# 3  jdoGEEy5s-5L1O_lNzEi2g
# 4  Mb0psF4WQF7gZSuZafVr-g
# 5  xw77viWz_BbmyntxoBVH4A

# %%
bdr_count = {}
for bd in df3['business_id']:
    if bd not in bdr_count.keys():
        bdr_count[bd] = 1
    else:
        bdr_count[bd] += 1

# %%
count_list = []
for bd in df3['business_id']:
    count_list.append(bdr_count[bd])

# %%
len(count_list)
# Out:
# 29471

# %%
count_list
# Out:
# [231,
#  10,
#  184,
#  20,
#  27,
#  4,
#  95,
#  16,
#  181,
#  430,
#  20,
#  63,
#  25,
#  69,
#  20,
#  7,
#  4,
#  69,
#  44,
#  15,
#  33,
#  17,
#  274,
#  158,
#  55,
#  41,
#  47,
#  274,
#  57,
#  5,
#  70,
#  270,
#  52,
#  7,
#  54,
#  47,
#  3,
#  21,
#  152,
#  32,
#  52,
#  16,
#  61,
#  27,
#  142,
#  30,
#  224,
#  66,
#  7,
#  430,
#  270,
#  93,
#  29,
#  92,
#  5,
#  25,
#  115,
#  22,
#  230,
#  17,
#  52,
#  10,
#  46,
#  4,
#  5,
#  17,
#  116,
#  145,
#  231,
#  6,
#  73,
#  25,
#  274,
#  4,
#  70,
#  29,
#  274,
#  4,
#  94,
#  95,
#  270,
#  59,
#  42,
#  12,
#  192,
#  69,
#  209,
#  3,
#  90,
#  41,
#  17,
#  4,
#  209,
#  42,
#  25,
#  4,
#  72,
#  26,
#  65,
#  231,
#  233,
#  11,
#  26,
#  16,
#  19,
#  142,
#  61,
#  35,
#  4,
#  24,
#  11,
#  93,
#  30,
#  99,
#  50,
#  229,
#  515,
#  143,
#  270,
#  83,
#  184,
#  3,
#  274,
#  231,
#  270,
#  19,
#  32,
#  116,
#  66,
#  56,
#  4,
#  99,
#  40,
#  73,
#  69,
#  78,
#  41,
#  515,
#  16,
#  9,
#  67,
#  15,
#  41,
#  157,
#  12,
#  27,
#  672,
#  78,
#  430,
#  4,
#  36,
#  120,
#  69,
#  1,
#  274,
#  28,
#  12,
#  672,
#  15,
#  32,
#  270,
#  59,
#  26,
#  55,
#  99,
#  52,
#  101,
#  672,
#  17,
#  42,
#  53,
#  21,
#  109,
#  18,
#  56,
#  2,
#  274,
#  67,
#  101,
#  231,
#  69,
#  63,
#  122,
#  7,
#  274,
#  69,
#  52,
#  7,
#  10,
#  672,
#  99,
#  50,
#  79,
#  22,
#  5,
#  116,
#  66,
#  515,
#  73,
#  37,
#  137,
#  30,
#  233,
#  71,
#  101,
#  51,
#  17,
#  28,
#  51,
#  138,
#  9,
#  274,
#  35,
#  63,
#  14,
#  32,
#  43,
#  69,
#  67,
#  11,
#  270,
#  229,
#  15,
#  16,
#  8,
#  672,
#  15,
#  69,
#  4,
#  9,
#  99,
#  16,
#  274,
#  8,
#  59,
#  12,
#  16,
#  78,
#  30,
#  178,
#  134,
#  18,
#  186,
#  7,
#  22,
#  20,
#  8,
#  76,
#  94,
#  21,
#  209,
#  83,
#  12,
#  4,
#  7,
#  98,
#  50,
#  11,
#  72,
#  78,
#  36,
#  8,
#  206,
#  15,
#  62,
#  430,
#  122,
#  515,
#  14,
#  23,
#  8,
#  40,
#  109,
#  99,
#  66,
#  186,
#  515,
#  31,
#  49,
#  36,
#  515,
#  5,
#  23,
#  26,
#  49,
#  83,
#  94,
#  52,
#  44,
#  6,
#  103,
#  50,
#  14,
#  84,
#  50,
#  15,
#  25,
#  36,
#  92,
#  27,
#  94,
#  231,
#  12,
#  8,
#  224,
#  60,
#  83,
#  68,
#  23,
#  2,
#  145,
#  19,
#  6,
#  15,
#  13,
#  43,
#  224,
#  158,
#  92,
#  20,
#  94,
#  15,
#  3,
#  56,
#  39,
#  99,
#  38,
#  72,
#  30,
#  13,
#  37,
#  38,
#  10,
#  12,
#  27,
#  61,
#  11,
#  78,
#  5,
#  109,
#  16,
#  84,
#  12,
#  25,
#  230,
#  36,
#  77,
#  515,
#  116,
#  14,
#  6,
#  515,
#  33,
#  18,
#  44,
#  55,
#  5,
#  186,
#  83,
#  151,
#  270,
#  11,
#  99,
#  75,
#  5,
#  231,
#  30,
#  66,
#  25,
#  7,
#  40,
#  47,
#  146,
#  5,
#  672,
#  5,
#  10,
#  115,
#  116,
#  178,
#  17,
#  274,
#  3,
#  672,
#  77,
#  66,
#  672,
#  76,
#  672,
#  32,
#  65,
#  515,
#  233,
#  33,
#  65,
#  116,
#  20,
#  152,
#  151,
#  36,
#  672,
#  76,
#  27,
#  14,
#  158,
#  49,
#  103,
#  6,
#  30,
#  158,
#  672,
#  99,
#  45,
#  515,
#  22,
#  119,
#  138,
#  51,
#  7,
#  233,
#  5,
#  86,
#  61,
#  26,
#  99,
#  8,
#  42,
#  116,
#  57,
#  81,
#  28,
#  83,
#  55,
#  95,
#  515,
#  80,
#  94,
#  12,
#  184,
#  138,
#  54,
#  47,
#  36,
#  27,
#  24,
#  146,
#  672,
#  90,
#  27,
#  24,
#  72,
#  25,
#  20,
#  25,
#  11,
#  12,
#  672,
#  119,
#  3,
#  3,
#  44,
#  24,
#  7,
#  11,
#  5,
#  61,
#  118,
#  79,
#  118,
#  672,
#  13,
#  69,
#  4,
#  274,
#  8,
#  138,
#  230,
#  672,
#  8,
#  430,
#  56,
#  672,
#  152,
#  28,
#  39,
#  186,
#  45,
#  35,
#  11,
#  138,
#  19,
#  3,
#  146,
#  48,
#  10,
#  67,
#  118,
#  117,
#  101,
#  52,
#  92,
#  16,
#  76,
#  8,
#  68,
#  3,
#  115,
#  37,
#  178,
#  230,
#  72,
#  4,
#  40,
#  36,
#  14,
#  80,
#  86,
#  47,
#  90,
#  109,
#  69,
#  32,
#  64,
#  3,
#  5,
#  7,
#  672,
#  22,
#  672,
#  47,
#  118,
#  75,
#  151,
#  36,
#  152,
#  672,
#  3,
#  92,
#  6,
#  52,
#  138,
#  270,
#  50,
#  672,
#  65,
#  12,
#  49,
#  430,
#  10,
#  3,
#  22,
#  515,
#  7,
#  145,
#  4,
#  24,
#  12,
#  42,
#  78,
#  79,
#  25,
#  15,
#  22,
#  94,
#  70,
#  13,
#  209,
#  34,
#  15,
#  3,
#  99,
#  5,
#  430,
#  152,
#  36,
#  7,
#  29,
#  3,
#  138,
#  430,
#  10,
#  672,
#  5,
#  138,
#  118,
#  157,
#  42,
#  515,
#  224,
#  44,
#  186,
#  73,
#  57,
#  270,
#  78,
#  10,
#  101,
#  22,
#  36,
#  20,
#  4,
#  27,
#  22,
#  181,
#  95,
#  49,
#  47,
#  430,
#  117,
#  20,
#  224,
#  52,
#  209,
#  672,
#  56,
#  84,
#  83,
#  2,
#  19,
#  143,
#  92,
#  672,
#  5,
#  184,
#  16,
#  209,
#  143,
#  32,
#  27,
#  83,
#  2,
#  134,
#  672,
#  46,
#  137,
#  32,
#  26,
#  43,
#  42,
#  116,
#  26,
#  430,
#  71,
#  158,
#  672,
#  117,
#  48,
#  36,
#  134,
#  28,
#  430,
#  41,
#  146,
#  209,
#  110,
#  158,
#  115,
#  50,
#  41,
#  430,
#  224,
#  270,
#  178,
#  13,
#  50,
#  44,
#  137,
#  35,
#  41,
#  20,
#  115,
#  72,
#  80,
#  94,
#  7,
#  515,
#  52,
#  42,
#  30,
#  54,
#  233,
#  78,
#  65,
#  6,
#  18,
#  138,
#  10,
#  62,
#  158,
#  6,
#  4,
#  158,
#  515,
#  78,
#  53,
#  224,
#  92,
#  515,
#  229,
#  32,
#  55,
#  138,
#  67,
#  43,
#  56,
#  79,
#  134,
#  30,
#  270,
#  34,
#  56,
#  98,
#  34,
#  95,
#  10,
#  6,
#  158,
#  36,
#  11,
#  42,
#  47,
#  95,
#  50,
#  27,
#  146,
#  39,
#  78,
#  3,
#  55,
#  23,
#  4,
#  515,
#  40,
#  66,
#  515,
#  233,
#  25,
#  47,
#  37,
#  118,
#  672,
#  17,
#  672,
#  31,
#  19,
#  16,
#  95,
#  30,
#  86,
#  11,
#  12,
#  17,
#  94,
#  50,
#  206,
#  86,
#  66,
#  233,
#  515,
#  80,
#  64,
#  11,
#  79,
#  69,
#  28,
#  66,
#  94,
#  134,
#  10,
#  23,
#  672,
#  8,
#  137,
#  224,
#  23,
#  78,
#  6,
#  118,
#  5,
#  25,
#  65,
#  4,
#  63,
#  54,
#  66,
#  7,
#  66,
#  11,
#  515,
#  4,
#  142,
#  50,
#  430,
#  25,
#  4,
#  99,
#  72,
#  206,
#  430,
#  83,
#  92,
#  231,
#  158,
#  36,
#  92,
#  22,
#  61,
#  3,
#  31,
#  20,
#  15,
#  37,
#  50,
#  49,
#  116,
#  12,
#  19,
#  65,
#  230,
#  63,
#  52,
#  4,
#  178,
#  90,
#  178,
#  47,
#  67,
#  7,
#  32,
#  76,
#  15,
#  94,
#  134,
#  672,
#  86,
#  515,
#  38,
#  44,
#  56,
#  42,
#  32,
#  115,
#  49,
#  83,
#  56,
#  23,
#  76,
#  6,
#  94,
#  36,
#  4,
#  92,
#  19,
#  672,
#  59,
#  42,
#  77,
#  151,
#  54,
#  3,
#  45,
#  56,
#  120,
#  69,
#  40,
#  192,
#  24,
#  3,
#  76,
#  17,
#  73,
#  47,
#  24,
#  64,
#  3,
#  81,
#  145,
#  75,
#  4,
#  672,
#  32,
#  94,
#  32,
#  11,
#  47,
#  49,
#  4,
#  515,
#  83,
#  40,
#  18,
#  94,
#  515,
#  75,
#  66,
#  5,
#  36,
#  99,
#  36,
#  36,
#  135,
#  101,
#  22,
#  117,
#  117,
#  36,
#  430,
#  29,
#  55,
#  33,
#  62,
#  72,
#  515,
#  116,
#  57,
#  14,
#  115,
#  138,
#  31,
#  143,
#  61,
#  6,
#  69,
#  178,
#  29,
#  672,
#  59,
#  515,
#  41,
#  52,
#  99,
#  430,
#  26,
#  73,
#  109,
#  36,
#  274,
#  81,
#  11,
#  25,
#  11,
#  33,
#  53,
#  230,
#  135,
#  4,
#  92,
#  118,
#  53,
#  45,
#  110,
#  515,
#  430,
#  4,
#  59,
#  5,
#  134,
#  430,
#  11,
#  99,
#  20,
#  50,
#  181,
#  61,
#  274,
#  36,
#  20,
#  21,
#  11,
#  37,
#  5,
#  40,
#  110,
#  224,
#  67,
#  109,
#  31,
#  15,
#  230,
#  7,
#  8,
#  7,
#  79,
#  79,
#  25,
#  10,
#  81,
#  672,
#  17,
#  134,
#  66,
#  20,
#  24,
#  83,
#  186,
#  61,
#  32,
#  231,
#  78,
#  79,
#  ...]

# %%
df3['business_id'].count()
# Out:
# 29471

# %%
df_sub = df3[['business_id','stars']]
df_count = pd.DataFrame({'business_id':df_sub.business_id,'stars':df_sub.stars,'business_review_count':count_list})
df_count.head()
# Out:
#               business_id  stars  business_review_count
# 0  6oRAC4uyJCsJl1X0WZpVSA    4.0                    231
# 2  rxQ2PIjhAx6dgAqUalf99Q    5.0                     10
# 3  EC9WB-iVjd28B6R6KIZ8TA    4.0                    184
# 4  LDJhwZN14AZOJyHjg2lkRw    4.0                     20
# 5  o5x6DF0KK1OBsiUOx2gavg    4.0                     27

# %%
x1 = df_count[['business_review_count']]
y1 = df_count[['stars']]
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1,random_state = 42,test_size = 0.3,shuffle = True)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x1_train, y1_train)
print(model.coef_)
print(model.intercept_)
# Out:
# [[0.00141606]]
# [3.59086612]

# %%
plt.scatter(x1_train,y1_train)

# %%
predict = model.predict(x1_test)

plt.scatter(y1_test, predict)

# %%
plt.hist(y1_test - predictions)
# Out:
# (array([ 720.,    0.,  841.,    0.,  123., 1215.,    0., 3085.,    0.,
#         2858.]),
#  array([-2.59794641, -2.19723838, -1.79653035, -1.39582232, -0.99511429,
#         -0.59440626, -0.19369823,  0.2070098 ,  0.60771782,  1.00842585,
#          1.40913388]),
#  <BarContainer object of 10 artists>)

# %%
# your code and solutions

# %% [markdown]
# ### Q3.3 Output the correlations between `business_review_count` and `useful` variables with `stars` and analyze the results.

# %%
# your code and solutions

# %%
plt.scatter(x1_test, predict)

# %%
plt.scatter(x_test,predictions)
